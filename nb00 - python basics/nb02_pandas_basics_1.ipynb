# %% [markdown]
# ### Pandas basics
#
# En aquest apartat veurem una de les llibreries més utilitzades alhora de realitzar anàlisis de dades: importar i exportar dades, realitzar operacions de tractament, etc..

# %% [markdown]
# ! conda install pandas -y

# %% [markdown]
# Activar la cel·la de codi esc+y. Instal·lar pandas, el posem desactivat (esc+r) perquè no s'executi cada vegada

# %%
import pandas as pd

# %% [markdown]
# Mòdul per exel·lencia per tractar dadaques no numeriques i numeriques a la vegada és Pandas. Numpy es per tractar arrays i dades nomès numèriques.

# %% [markdown]
# A Pandas hi ha dos objectes principals: el **DataFrame** i les **Series**
#
# ## DataFrame
# ---------------------
# La classe [*DataFrame*](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) és una de les més utilitzades per tractar les dades. Un DataFrame és una taula de doble entrada (files i columnes).
#
# Data frame &rarr; equivalencia a una taula de SQL.
#
# Per exemple:

# %%
data = {'Nom':['Pere', 'Alice', 'Marta', 'Tom'],
        'Edat':[20, 21, 19, 18]}

pd.DataFrame(data)
# Out:
#      Nom  Edat
# 0   Pere    20
# 1  Alice    21
# 2  Marta    19
# 3    Tom    18

# %% [markdown]
# Tipu diccionari de python, hasmap de java.

# %%
pd.DataFrame({ 
    'clau':['A','B','C','A','B','C'] ,
    'valors' : range(6) 
    }, 
    columns = ['valors','clau'] 
)
# Out:
#    valors clau
# 0       0    A
# 1       1    B
# 2       2    C
# 3       3    A
# 4       4    B
# 5       5    C

# %% [markdown]
# Els valors de les columnes no han de ser número poden ser cadenes de text. A més, també podem assignar etiquetes a les files de la taula mitjançant el paràmetre index.

# %% [markdown]
# El data frame sempre afegeix un index i no té perquè ser sempre numèric, si no l'especifiquem és numèric, però el podem generar nosaltres. Per Exemple:

# %%
pd.DataFrame({'Pere': ['M\'agrada', 'No m\'agrada'], 
              'Marta': ['No està malament', 'M\'agrada']},
             index=['Producte A', 'Producte B'])
# Out:
#                    Pere             Marta
# Producte A     M'agrada  No està malament
# Producte B  No m'agrada          M'agrada

# %% [markdown]
# Ens serveix per com accedim després a les ddades. Serveix per identificar cada registre.

# %% [markdown]
# ## Series
# ---------------------
#
# Una sèrie, és senzillament una seqüència de valors de dades. Si un DataFrame és una taula, una Sèrie és una llista. I, de fet, es poden crear mitjanpodeu crear-ne un amb res més que una llista:
# La classe [*Serie*](https://pandas.pydata.org/docs/reference/series.html) és una única columna d'un DataFrame i com a tal podem assignar-li etiquetes a la fila.
#
# És un vector de numpy, en pandas sería series. Una matriu amb numpy és un data frame amb pandas.
#
# Una sèrie ha de ser numerica o alphanumèrica, no barrejat.
#
# Pot passar a formar part d'una taula o data frame.
#
# Series està indexat, però no és una taula, és com l'index de l'array, però amb la diferència que pot ser alphanumèric, index amb altes capacitats.
#
# Per exemple:

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# Exemple de index diferent. i veiem que si que pot tenir un nom, sería com una columna de una taula.

# %%
pd.Series([30, 35, 40], index=['2015 Vendes', '2016 Vendes', '2017 Vendes'], name='Producte A')
# Out:
# 2015 Vendes    30
# 2016 Vendes    35
# 2017 Vendes    40
# Name: Producte A, dtype: int64

# %% [markdown]
# ## Importació
# ---------------------
#
# Podem importar dades a DataFrames de Pandas de diferents orígen i formats. Alguns dels més utilitzats són:
#
# Comandes per generar un Data Frame a partir de dades:
#
# * De CSV: con [`read_csv`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)
# * De Excel: con [`read_excel`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html)
# * De base de datos: con [`read_sql`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql.html)
# * La més genèrica és [`read_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html)
#
#
# En aquest exemple veiem la manera d'importar les dades a partir d'un fitxer CSV. Aquest fitxer conté dades d'anuncis de venda de cotxes de segona mà de diferents plataformes. Origen del [dataset](https://www.kaggle.com/datasets/datamarket/venta-de-coches)
#
# **Nota:** Per poder manipular base de dades SQLite podem utilitzar l'eina [DB Browser for SQLite ](https://sqlitebrowser.org/)

# %%
#Importar dadades des d'un CSV

cotxes = pd.read_csv('../Notebooks/Dades/cars/venda-cotxes-segona-ma.csv')
cotxes.head()
# Out:
#                             company           make     model  \
# 0  9881BCDD5A0AD4733037B3FB25E69C3A            KIA  Carnival
# 1  9881BCDD5A0AD4733037B3FB25E69C3A            BMW   Serie 5
# 2  9881BCDD5A0AD4733037B3FB25E69C3A           FIAT       500
# 3  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL     Astra
# 4  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase C
#
#                                           version  price  price_financed  \
# 0                KIA Carnival 2.9 CRDi VGT EX 5p.   4860          4860.0
# 1                                BMW Serie 5  4p.   1800             NaN
# 2            FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490          6490.0
# 3                                 OPEL Astra  3p.   5550             NaN
# 4  MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990         11490.0
#
#        fuel  year     kms  power  doors       shift              color  \
# 0    Diésel  2007  221000  185.0    5.0      Manual  Beige (champagne)
# 1    Diésel  2001  205000    NaN    4.0      Manual              Verde
# 2  Gasolina  2017   75000   69.0    3.0      Manual              Negro
# 3    Diésel  2009  137000    NaN    3.0      Manual               Rojo
# 4    Diésel  2008   95000  170.0    4.0  Automático       Gris / Plata
#
#    photos  is_professional                            dealer  \
# 0       8             True                          VM Motor
# 1       0            False  3F128E570B3A9009D7B52A0523AF43DD
# 2       7             True                  LAS PALMAS MOTOR
# 3       0            False  22003DEA67E7C5BE6022A29E677668BC
# 4      21             True                       Autos Lipiz
#
#                               phone    province         publish_date  \
# 0                         928493782  Las Palmas  2020-12-22 13:28:36
# 1  DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 2                         653895468  Las Palmas  2020-11-20 18:30:00
# 3  67990DA67E557C1D0C1B6D1DB731938C   Barcelona  2020-11-21 16:37:13
# 4                         646179040      Madrid  2020-11-05 19:09:27
#
#            insert_date
# 0  2020-12-25 00:00:00
# 1  2020-12-26 00:00:00
# 2  2020-12-08 00:00:00
# 3  2020-11-24 00:00:00
# 4  2020-12-01 00:00:00

# %% [markdown]
# La variable ``cotxes`` és un data frame que tindrà una sèrie d'atributs .head() per defecte són 5, però podem passar un parametre.

# %% [markdown]
# Alguns dels paràmetres més importants de read_csv són:
# * delimiter: Indica quin caràcter és el delimitador de valors en el cas d'un CSV seràn les comes
# * decimal: Indica quin caràcter s'utilitza com a separador de milers
# * encoding: Indica la codificació de caràcters amb la qual ha de llegir el fitxer. El més usual és "utf-8"

# %% [markdown]
# Si no té capçelera li podem dir nosaltres quina ha de ser.

# %% [raw]
# ! conda install openpyxl -y

# %%
#Importar dadades des d'un Excel
cotxes = pd.read_excel('../Notebooks/Dades/cars/venda-cotxes-segona-ma.xlsx', index_col = 0)
# Si index col és False l'auto genera, si li dius a 0, li dius quina columna fa de index
cotxes.head()
# Out:
#                                            make     model  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A            KIA  Carnival
# 9881BCDD5A0AD4733037B3FB25E69C3A            BMW   Serie 5
# 9881BCDD5A0AD4733037B3FB25E69C3A           FIAT       500
# 9881BCDD5A0AD4733037B3FB25E69C3A           OPEL     Astra
# 9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase C
#
#                                                                          version  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A                KIA Carnival 2.9 CRDi VGT EX 5p.
# 9881BCDD5A0AD4733037B3FB25E69C3A                                BMW Serie 5  4p.
# 9881BCDD5A0AD4733037B3FB25E69C3A            FIAT 500 1.2 8v 51kW 69CV Lounge 3p.
# 9881BCDD5A0AD4733037B3FB25E69C3A                                 OPEL Astra  3p.
# 9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.
#
#                                   price  price_financed      fuel  year  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A   4860         48600.0    Diésel  2007
# 9881BCDD5A0AD4733037B3FB25E69C3A   1800             NaN    Diésel  2001
# 9881BCDD5A0AD4733037B3FB25E69C3A   6490         64900.0  Gasolina  2017
# 9881BCDD5A0AD4733037B3FB25E69C3A   5550             NaN    Diésel  2009
# 9881BCDD5A0AD4733037B3FB25E69C3A  11990        114900.0    Diésel  2008
#
#                                      kms   power  doors       shift  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A  221000  1850.0   50.0      Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A  205000     NaN   40.0      Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A   75000   690.0   30.0      Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A  137000     NaN   30.0      Manual
# 9881BCDD5A0AD4733037B3FB25E69C3A   95000  1700.0   40.0  Automático
#
#                                               color  photos  is_professional  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A  Beige (champagne)       8             True
# 9881BCDD5A0AD4733037B3FB25E69C3A              Verde       0            False
# 9881BCDD5A0AD4733037B3FB25E69C3A              Negro       7             True
# 9881BCDD5A0AD4733037B3FB25E69C3A               Rojo       0            False
# 9881BCDD5A0AD4733037B3FB25E69C3A       Gris / Plata      21             True
#
#                                                             dealer  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A                          VM Motor
# 9881BCDD5A0AD4733037B3FB25E69C3A  3F128E570B3A9009D7B52A0523AF43DD
# 9881BCDD5A0AD4733037B3FB25E69C3A                  LAS PALMAS MOTOR
# 9881BCDD5A0AD4733037B3FB25E69C3A  22003DEA67E7C5BE6022A29E677668BC
# 9881BCDD5A0AD4733037B3FB25E69C3A                       Autos Lipiz
#
#                                                              phone  \
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A                         928493782
# 9881BCDD5A0AD4733037B3FB25E69C3A  DBB2949B54A306BA299A791B860EEBF6
# 9881BCDD5A0AD4733037B3FB25E69C3A                         653895468
# 9881BCDD5A0AD4733037B3FB25E69C3A  67990DA67E557C1D0C1B6D1DB731938C
# 9881BCDD5A0AD4733037B3FB25E69C3A                         646179040
#
#                                     province        publish_date insert_date
# company
# 9881BCDD5A0AD4733037B3FB25E69C3A  Las Palmas 2020-12-22 13:28:36  2020-12-25
# 9881BCDD5A0AD4733037B3FB25E69C3A   Tarragona 2020-12-14 07:02:22  2020-12-26
# 9881BCDD5A0AD4733037B3FB25E69C3A  Las Palmas 2020-11-20 18:30:00  2020-12-08
# 9881BCDD5A0AD4733037B3FB25E69C3A   Barcelona 2020-11-21 16:37:13  2020-11-24
# 9881BCDD5A0AD4733037B3FB25E69C3A      Madrid 2020-11-05 19:09:27  2020-12-01

# %%
#Importar dadades des d'una BD SQL (SQLite)
import sqlite3

# %%
# Creem una conexió a la base de dades SQLite
con = sqlite3.connect("../Notebooks/Dades/cars/venda-cotxes-segona-ma.db")
# Hauríes de tenir unes credencials que hauríem de passar com a paràmetres. Però aquí tenim el fitxer directament

cotxes = pd.read_sql("SELECT * FROM cotxes", con)
cotxes.head()

#Tanquem la connexió
con.close()

# %%
# Si volem saber el tamany del DataFrame utilitzarem la propietat shape (quantitat de files i columnes)
cotxes.shape
# Out:
# (5000, 20)

# %%
# Noms de les columnes
cotxes.columns
# Out:
# Index(['company', 'make', 'model', 'version', 'price', 'price_financed',
#        'fuel', 'year', 'kms', 'power', 'doors', 'shift', 'color', 'photos',
#        'is_professional', 'dealer', 'phone', 'province', 'publish_date',
#        'insert_date'],
#       dtype='object')

# %% [markdown]
# ### Accés a les dades
#
# Podem accedir a les columnes del DataFrame mitjançant el nom de la columna.

# %%
# Retorna tot els valors de la columna price
cotxes.price # Retorna la columna
# Out:
# 0        4860
# 1        1800
# 2        6490
# 3        5550
# 4       11990
#         ...
# 4995    10200
# 4996     7650
# 4997     6200
# 4998    49900
# 4999    12950
# Name: price, Length: 5000, dtype: int64

# %%
# Retorna quin és el valor màxim de la columna preu
cotxes.price.max(), cotxes.price.min()
# Out:
# (319900, 300)

# %%
# Retorna quina és la posició del valor màxim de la columna preu
cotxes.price.argmax()
# Out:
# 666

# %% [markdown]
# Diferencia entre max i argmax. el segon quin és l'argument que tè el màxim (posició = index)
#
# Si n'hi ha dos, retorna el primer (ja ens hi trobarem, jaja, profe crak)
#
# Igualment hi ha el mínim

# %%
# Retorna la mitjana de la columna preu
cotxes.price.mean()
# Out:
# 15051.3718

# %%
# Si volem veure els valors únics d'un camp (quines marques tenim)
cotxes.make.unique()
# Out:
# array(['KIA', 'BMW', 'FIAT', 'OPEL', 'MERCEDES-BENZ', 'PEUGEOT',
#        'VOLKSWAGEN', 'FORD', 'RENAULT', 'CITROEN', 'SEAT', 'VOLVO',
#        'NISSAN', 'LAND-ROVER', 'MINI', 'AUDI', 'HONDA', 'DS', 'SKODA',
#        'MITSUBISHI', 'LEXUS', 'BENTLEY', 'ROVER', 'PORSCHE', 'FERRARI',
#        'HYUNDAI', 'TOYOTA', 'DACIA', 'MAZDA', 'ALFA ROMEO', 'INFINITI',
#        'JAGUAR', 'LANCIA', 'CHEVROLET', 'ABARTH', 'SSANGYONG', 'JEEP',
#        'SMART', 'SUZUKI', 'SAAB', 'DFSK', 'SUBARU', 'MASERATI', 'IVECO',
#        'ASTON MARTIN', 'DODGE', 'CHRYSLER', 'ROLLS-ROYCE', 'HUMMER',
#        'TESLA', 'DAEWOO', 'ISUZU', 'MG', 'LADA', 'TATA', 'GALLOPER'],
#       dtype=object)

# %% [markdown]
# Extreu valors únics. Extreu informació de la columna make. La botiga de cotxes de segona mà té 8 o 10 bmw, però aquesta funció recorre la taula i cada nova taula la guarda, nomès se'n queda una.

# %%
# Volem contar quants vehicles hi ha de cada marca
cotxes.make.value_counts() #ordenats de més a menys
# Out:
# VOLKSWAGEN       497
# BMW              462
# MERCEDES-BENZ    404
# AUDI             351
# RENAULT          346
# PEUGEOT          342
# FORD             306
# OPEL             298
# CITROEN          288
# SEAT             258
# TOYOTA           156
# NISSAN           143
# FIAT             124
# HYUNDAI          106
# KIA               96
# VOLVO             89
# SKODA             70
# LAND-ROVER        67
# MINI              66
# MAZDA             54
# HONDA             47
# PORSCHE           42
# MITSUBISHI        37
# JAGUAR            36
# ALFA ROMEO        33
# SUZUKI            29
# LEXUS             28
# CHEVROLET         25
# JEEP              21
# DACIA             18
# SMART             18
# ABARTH            17
# SSANGYONG         17
# DS                16
# SUBARU            13
# CHRYSLER          12
# SAAB               9
# INFINITI           6
# FERRARI            6
# MASERATI           6
# ROVER              5
# LANCIA             4
# BENTLEY            4
# IVECO              4
# ISUZU              3
# DAEWOO             3
# DODGE              3
# ASTON MARTIN       3
# ROLLS-ROYCE        2
# TESLA              2
# DFSK               2
# MG                 2
# HUMMER             1
# LADA               1
# TATA               1
# GALLOPER           1
# Name: make, dtype: int64

# %% [markdown]
# #### Filtre i/o selecció

# %% [markdown]
# Per poder seleccionar un subconjunt de les dades que tenim en un Dataframe podem utilitzar les porpietats `loc`, `iloc` i `[]`.
# - amb `loc` accedirem al grup de files i columnes mitjançant etiquetes o bé amb un array de booleans.
# - amb `iloc` accedim al grup de files i columnes mitjançant posicions.
# - amb `[]` podem filtrar per condicions.
#
# [https://pandas.pydata.org/docs/user_guide/indexing.html](https://pandas.pydata.org/docs/user_guide/indexing.html#)
#
# Aquests mètodes retornen un altre DataFrame.

# %% [markdown]
# #### Selecció per índexs (`iloc`)
#
# Per accedir per posició utilitzant indexos numèrics , utilitzarem iloc[] i dins dels claudators indicarem els índexs de les les files i les columnes que volem seleccionar
#
# [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)
#
# Cal tenir en compte que Python utilitza el 0 com a primer valor d'un índex.
#
#
# ```python
# # Sintaxi
# iloc[<número de files>]
# iloc[<índex primera fila>:<índex última fila>,<índex primera col>:<índex última col>]
# iloc[<índex fila a seleccionar>,<índex columna a seleccionar>]
# iloc[[<índexs de les files no consecutives a seleccionar>],[<índexs de les columnes no consecutives a seleccionar>]]
# ```

# %% [markdown]
# a x = 5, x, és un punter que apunta a la memòria que apunta a uns bits que representen el 5.
#
# Si fem x = y, depen de com sigui el llenguatge, y pot ser el mateix punter (fer una còpia). Si modifiques un, modifiques l'altre.
#
# Amb python &rarr; ``y = deepcopy(x)``. Crea una variable nova i seran independents.
#
# Són dos nivells de fer copies.
#
# Això són vistes ``x=cotxes.iloc[:,:]`` no són copies, apunten a la mateixa posició de memòria.
#
# Exemple
#
# ```python
# vista = cotxes.iloc[:,:]
# vista.iloc[1:2,2:3] = "nou model"
# ```
# Vista, serà una deepcopy. En teoría no hauría de deixar canviar

# %%
# Seleccionem totes les files i totes les columnes (no filtrem res)
cotxes.iloc[:,:]
# Out:
#                                company           make      model  \
# 0     9881BCDD5A0AD4733037B3FB25E69C3A            KIA   Carnival
# 1     9881BCDD5A0AD4733037B3FB25E69C3A            BMW    Serie 5
# 2     9881BCDD5A0AD4733037B3FB25E69C3A           FIAT        500
# 3     9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Astra
# 4     9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ    Clase C
# ...                                ...            ...        ...
# 4995  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Corsa
# 4996  9881BCDD5A0AD4733037B3FB25E69C3A         TOYOTA      Auris
# 4997  9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT    Partner
# 4998  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ  GLC Coupé
# 4999  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase SL
#
#                                               version  price  price_financed  \
# 0                    KIA Carnival 2.9 CRDi VGT EX 5p.   4860          4860.0
# 1                                    BMW Serie 5  4p.   1800             NaN
# 2                FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490          6490.0
# 3                                     OPEL Astra  3p.   5550             NaN
# 4      MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990         11490.0
# ...                                               ...    ...             ...
# 4995           OPEL Corsa 1.4 66kW 90CV Selective 5p.  10200          9400.0
# 4996  TOYOTA Auris 1.2 120T Active Touring Sports 5p.   7650             NaN
# 4997                             PEUGEOT Partner  5p.   6200             NaN
# 4998     MERCEDES-BENZ GLC Coupe GLC 220 d 4MATIC 5p.  49900         48000.0
# 4999                MERCEDES-BENZ Clase SL SL 500 2p.  12950             NaN
#
#           fuel  year     kms  power  doors       shift              color  \
# 0       Diésel  2007  221000  185.0    5.0      Manual  Beige (champagne)
# 1       Diésel  2001  205000    NaN    4.0      Manual              Verde
# 2     Gasolina  2017   75000   69.0    3.0      Manual              Negro
# 3       Diésel  2009  137000    NaN    3.0      Manual               Rojo
# 4       Diésel  2008   95000  170.0    4.0  Automático       Gris / Plata
# ...        ...   ...     ...    ...    ...         ...                ...
# 4995  Gasolina  2018   18318   90.0    5.0      Manual    Blanco (Alpino)
# 4996  Gasolina  2016  157000  116.0    5.0      Manual               Azul
# 4997    Diésel  2012  125000    NaN    5.0      Manual             Blanco
# 4998    Diésel  2019      15  170.0    5.0  Automático       Gris / Plata
# 4999  Gasolina  2003  129000  306.0    2.0  Automático              Negro
#
#       photos is_professional                            dealer  \
# 0          8            True                          VM Motor
# 1          0           False  3F128E570B3A9009D7B52A0523AF43DD
# 2          7            True                  LAS PALMAS MOTOR
# 3          0           False  22003DEA67E7C5BE6022A29E677668BC
# 4         21            True                       Autos Lipiz
# ...      ...             ...                               ...
# 4995      32            True                     Vara de Quart
# 4996       5           False  9448B9C35DDD44F451DC88E988CC3A03
# 4997       0           False  92EAF3719159C372F3D50337E0A14F57
# 4998      11            True             Autocas Mercedes Benz
# 4999      30            True                          Autofesa
#
#                                  phone    province         publish_date  \
# 0                            928493782  Las Palmas  2020-12-22 13:28:36
# 1     DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 2                            653895468  Las Palmas  2020-11-20 18:30:00
# 3     67990DA67E557C1D0C1B6D1DB731938C   Barcelona  2020-11-21 16:37:13
# 4                            646179040      Madrid  2020-11-05 19:09:27
# ...                                ...         ...                  ...
# 4995                         689851902    Valencia  2020-11-23 16:24:28
# 4996  67ABDCB290BF2A7CA8D3E84C9007BF9A   Tarragona  2020-11-10 15:27:32
# 4997  A31DAA15140D41FD522BC3DF2341D5A1     Sevilla  2020-10-10 05:51:41
# 4998                         964222200   Castellón  2020-11-20 09:43:44
# 4999                         910380569      Madrid  2021-01-19 09:40:55
#
#               insert_date
# 0     2020-12-25 00:00:00
# 1     2020-12-26 00:00:00
# 2     2020-12-08 00:00:00
# 3     2020-11-24 00:00:00
# 4     2020-12-01 00:00:00
# ...                   ...
# 4995  2020-11-26 00:00:00
# 4996  2021-01-10 00:00:00
# 4997  2020-12-16 00:00:00
# 4998  2020-11-28 00:00:00
# 4999  2021-01-20 00:00:00
#
# [5000 rows x 20 columns]

# %%
# Seleccionem les 5 primeres observacions
cotxes.iloc[:5]
# Out:
#                             company           make     model  \
# 0  9881BCDD5A0AD4733037B3FB25E69C3A            KIA  Carnival
# 1  9881BCDD5A0AD4733037B3FB25E69C3A            BMW   Serie 5
# 2  9881BCDD5A0AD4733037B3FB25E69C3A           FIAT       500
# 3  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL     Astra
# 4  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase C
#
#                                           version  price  price_financed  \
# 0                KIA Carnival 2.9 CRDi VGT EX 5p.   4860          4860.0
# 1                                BMW Serie 5  4p.   1800             NaN
# 2            FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490          6490.0
# 3                                 OPEL Astra  3p.   5550             NaN
# 4  MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990         11490.0
#
#        fuel  year     kms  power  doors       shift              color  \
# 0    Diésel  2007  221000  185.0    5.0      Manual  Beige (champagne)
# 1    Diésel  2001  205000    NaN    4.0      Manual              Verde
# 2  Gasolina  2017   75000   69.0    3.0      Manual              Negro
# 3    Diésel  2009  137000    NaN    3.0      Manual               Rojo
# 4    Diésel  2008   95000  170.0    4.0  Automático       Gris / Plata
#
#    photos is_professional                            dealer  \
# 0       8            True                          VM Motor
# 1       0           False  3F128E570B3A9009D7B52A0523AF43DD
# 2       7            True                  LAS PALMAS MOTOR
# 3       0           False  22003DEA67E7C5BE6022A29E677668BC
# 4      21            True                       Autos Lipiz
#
#                               phone    province         publish_date  \
# 0                         928493782  Las Palmas  2020-12-22 13:28:36
# 1  DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 2                         653895468  Las Palmas  2020-11-20 18:30:00
# 3  67990DA67E557C1D0C1B6D1DB731938C   Barcelona  2020-11-21 16:37:13
# 4                         646179040      Madrid  2020-11-05 19:09:27
#
#            insert_date
# 0  2020-12-25 00:00:00
# 1  2020-12-26 00:00:00
# 2  2020-12-08 00:00:00
# 3  2020-11-24 00:00:00
# 4  2020-12-01 00:00:00

# %%
# Seleccionem totes les files i la primera columna (company)
cotxes.iloc[:, 0]
# Out:
# 0       9881BCDD5A0AD4733037B3FB25E69C3A
# 1       9881BCDD5A0AD4733037B3FB25E69C3A
# 2       9881BCDD5A0AD4733037B3FB25E69C3A
# 3       9881BCDD5A0AD4733037B3FB25E69C3A
# 4       9881BCDD5A0AD4733037B3FB25E69C3A
#                       ...
# 4995    9881BCDD5A0AD4733037B3FB25E69C3A
# 4996    9881BCDD5A0AD4733037B3FB25E69C3A
# 4997    9881BCDD5A0AD4733037B3FB25E69C3A
# 4998    9881BCDD5A0AD4733037B3FB25E69C3A
# 4999    9881BCDD5A0AD4733037B3FB25E69C3A
# Name: company, Length: 5000, dtype: object

# %%
# Seleccionem la última columna (insert_date)
cotxes.iloc[:, -1]
# Out:
# 0       2020-12-25 00:00:00
# 1       2020-12-26 00:00:00
# 2       2020-12-08 00:00:00
# 3       2020-11-24 00:00:00
# 4       2020-12-01 00:00:00
#                ...
# 4995    2020-11-26 00:00:00
# 4996    2021-01-10 00:00:00
# 4997    2020-12-16 00:00:00
# 4998    2020-11-28 00:00:00
# 4999    2021-01-20 00:00:00
# Name: insert_date, Length: 5000, dtype: object

# %%
# Seleccionem les files de la 10 a la 20 i les columnes 2 i 3
cotxes.iloc[10:21, 2:4]
# Out:
#                model                                            version
# 10           Clase M                                      MERCEDES-BENZ
# 11            Mégane               RENAULT Megane Dynamique dCi 110 5p.
# 12          Berlingo           CITROEN Berlingo 1.6 HDi 90 XTR Plus 5p.
# 13   Clase GLE Coupé  MERCEDES-BENZ Clase GLE Coupe MercedesAMG GLE ...
# 14          Berlingo                                            CITROEN
# 15        C4 Picasso         CITROEN C4 Picasso BlueHDi 120cv Shine 5p.
# 16             Ateca   SEAT Ateca 1.0 TSI 85kW 115CV StSp Style Eco 5p.
# 17      Kangoo Combi  RENAULT Kangoo Combi Profesional M1AF En. dCi ...
# 18        C4 Picasso       CITROEN C4 Picasso 1.6 VTi 120cv Premier 5p.
# 19           Clase A                  MERCEDES-BENZ Clase A A 180 d 5p.
# 20  Grandland X PHEV  OPEL Grandland X PHEV 1.6 Turbo Ultimate Auto ...

# %%
# Seleccionem totes les columnes excepte la última
cotxes.iloc[:, :-1]
# Out:
#                                company           make      model  \
# 0     9881BCDD5A0AD4733037B3FB25E69C3A            KIA   Carnival
# 1     9881BCDD5A0AD4733037B3FB25E69C3A            BMW    Serie 5
# 2     9881BCDD5A0AD4733037B3FB25E69C3A           FIAT        500
# 3     9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Astra
# 4     9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ    Clase C
# ...                                ...            ...        ...
# 4995  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Corsa
# 4996  9881BCDD5A0AD4733037B3FB25E69C3A         TOYOTA      Auris
# 4997  9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT    Partner
# 4998  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ  GLC Coupé
# 4999  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase SL
#
#                                               version  price  price_financed  \
# 0                    KIA Carnival 2.9 CRDi VGT EX 5p.   4860          4860.0
# 1                                    BMW Serie 5  4p.   1800             NaN
# 2                FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490          6490.0
# 3                                     OPEL Astra  3p.   5550             NaN
# 4      MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990         11490.0
# ...                                               ...    ...             ...
# 4995           OPEL Corsa 1.4 66kW 90CV Selective 5p.  10200          9400.0
# 4996  TOYOTA Auris 1.2 120T Active Touring Sports 5p.   7650             NaN
# 4997                             PEUGEOT Partner  5p.   6200             NaN
# 4998     MERCEDES-BENZ GLC Coupe GLC 220 d 4MATIC 5p.  49900         48000.0
# 4999                MERCEDES-BENZ Clase SL SL 500 2p.  12950             NaN
#
#           fuel  year     kms  power  doors       shift              color  \
# 0       Diésel  2007  221000  185.0    5.0      Manual  Beige (champagne)
# 1       Diésel  2001  205000    NaN    4.0      Manual              Verde
# 2     Gasolina  2017   75000   69.0    3.0      Manual              Negro
# 3       Diésel  2009  137000    NaN    3.0      Manual               Rojo
# 4       Diésel  2008   95000  170.0    4.0  Automático       Gris / Plata
# ...        ...   ...     ...    ...    ...         ...                ...
# 4995  Gasolina  2018   18318   90.0    5.0      Manual    Blanco (Alpino)
# 4996  Gasolina  2016  157000  116.0    5.0      Manual               Azul
# 4997    Diésel  2012  125000    NaN    5.0      Manual             Blanco
# 4998    Diésel  2019      15  170.0    5.0  Automático       Gris / Plata
# 4999  Gasolina  2003  129000  306.0    2.0  Automático              Negro
#
#       photos is_professional                            dealer  \
# 0          8            True                          VM Motor
# 1          0           False  3F128E570B3A9009D7B52A0523AF43DD
# 2          7            True                  LAS PALMAS MOTOR
# 3          0           False  22003DEA67E7C5BE6022A29E677668BC
# 4         21            True                       Autos Lipiz
# ...      ...             ...                               ...
# 4995      32            True                     Vara de Quart
# 4996       5           False  9448B9C35DDD44F451DC88E988CC3A03
# 4997       0           False  92EAF3719159C372F3D50337E0A14F57
# 4998      11            True             Autocas Mercedes Benz
# 4999      30            True                          Autofesa
#
#                                  phone    province         publish_date
# 0                            928493782  Las Palmas  2020-12-22 13:28:36
# 1     DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 2                            653895468  Las Palmas  2020-11-20 18:30:00
# 3     67990DA67E557C1D0C1B6D1DB731938C   Barcelona  2020-11-21 16:37:13
# 4                            646179040      Madrid  2020-11-05 19:09:27
# ...                                ...         ...                  ...
# 4995                         689851902    Valencia  2020-11-23 16:24:28
# 4996  67ABDCB290BF2A7CA8D3E84C9007BF9A   Tarragona  2020-11-10 15:27:32
# 4997  A31DAA15140D41FD522BC3DF2341D5A1     Sevilla  2020-10-10 05:51:41
# 4998                         964222200   Castellón  2020-11-20 09:43:44
# 4999                         910380569      Madrid  2021-01-19 09:40:55
#
# [5000 rows x 19 columns]

# %% [markdown]
# ### Especifiquem una llista de indexos (make, model, price)
# El que retorna, en diem view (com a sql) &rarr; la podem assignar a una variable

# %%
# Seleccionem les columnes 1, 2, 4 (columnes no consecutives, per ex. make, model, price)
cotxes.iloc[:, [1, 2, 4]]
# Out:
#                make      model  price
# 0               KIA   Carnival   4860
# 1               BMW    Serie 5   1800
# 2              FIAT        500   6490
# 3              OPEL      Astra   5550
# 4     MERCEDES-BENZ    Clase C  11990
# ...             ...        ...    ...
# 4995           OPEL      Corsa  10200
# 4996         TOYOTA      Auris   7650
# 4997        PEUGEOT    Partner   6200
# 4998  MERCEDES-BENZ  GLC Coupé  49900
# 4999  MERCEDES-BENZ   Clase SL  12950
#
# [5000 rows x 3 columns]

# %% [markdown]
# ##### Exercicis `iloc`
#
# Del dataset venda-cotxes-segona-ma.csv
#
# * Mostra la fila 10, però només volem la marca i el model del cotxe

# %%
cotxes.iloc[:11,[1]]
# Out:
#              make
# 0             KIA
# 1             BMW
# 2            FIAT
# 3            OPEL
# 4   MERCEDES-BENZ
# 5            OPEL
# 6         PEUGEOT
# 7      VOLKSWAGEN
# 8            OPEL
# 9            FORD
# 10  MERCEDES-BENZ

# %% [markdown]
# #### Selecció per etiquetes (`loc`)

# %% [markdown]
# Amb `loc` podem seleccionar un grup de files i/o columnes a través d'etiquetes o un array de booleans.
#
# [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html)
#
#
# * Una sola etiqueta, per exemple. `5` or `'a'`, (el 5 és interpretat com una etiqueta i no com un índex).
# * Un array d'etiquetes, per exemple. `['a', 'b', 'c']`.
# * Un rang/tall d'objectes amb etiques, per exemple. 'a':'f'.
# * Un array de booleans amb la mateixa longitud que el número de columnes. True significarà que volem la columna i False no.

# %%
# Seleccionem totes les files i només mostrarem les columnes `make` i `price`
cotxes.loc[:,['make','price']] # Podríem posar [0:10] -> perquè el nom de la fila és aquest,
# No pq sigui idx
# Si ho fes per idx (amb iloc), sortiría de les files de la 0 a 9.
# El [0:10] -> s'expandexi com una llista amb tots els valors que hi han al mig
# Si retorna un, sería un data series si n'hi han més sería un data frame, encara que sigui el 
# mateix tindría una forma diferent.
# El [] el que fa és expandir fins al següent sempre i quan siguin únics. Si canviem el index al 
# fabricant, no cal que sigui únic, però es pot fer és una guarrada i passen coses com aquesta, 
# es pot fer però s'ha de vigilar.
# Out:
#                make  price
# 0               KIA   4860
# 1               BMW   1800
# 2              FIAT   6490
# 3              OPEL   5550
# 4     MERCEDES-BENZ  11990
# ...             ...    ...
# 4995           OPEL  10200
# 4996         TOYOTA   7650
# 4997        PEUGEOT   6200
# 4998  MERCEDES-BENZ  49900
# 4999  MERCEDES-BENZ  12950
#
# [5000 rows x 2 columns]

# %%
# Seleccionem totes les files i les columnes compreses entre `make` i `fuel`
cotxes.loc[:, 'make':'fuel']
# Out:
#                make      model  \
# 0               KIA   Carnival
# 1               BMW    Serie 5
# 2              FIAT        500
# 3              OPEL      Astra
# 4     MERCEDES-BENZ    Clase C
# ...             ...        ...
# 4995           OPEL      Corsa
# 4996         TOYOTA      Auris
# 4997        PEUGEOT    Partner
# 4998  MERCEDES-BENZ  GLC Coupé
# 4999  MERCEDES-BENZ   Clase SL
#
#                                               version  price  price_financed  \
# 0                    KIA Carnival 2.9 CRDi VGT EX 5p.   4860          4860.0
# 1                                    BMW Serie 5  4p.   1800             NaN
# 2                FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490          6490.0
# 3                                     OPEL Astra  3p.   5550             NaN
# 4      MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990         11490.0
# ...                                               ...    ...             ...
# 4995           OPEL Corsa 1.4 66kW 90CV Selective 5p.  10200          9400.0
# 4996  TOYOTA Auris 1.2 120T Active Touring Sports 5p.   7650             NaN
# 4997                             PEUGEOT Partner  5p.   6200             NaN
# 4998     MERCEDES-BENZ GLC Coupe GLC 220 d 4MATIC 5p.  49900         48000.0
# 4999                MERCEDES-BENZ Clase SL SL 500 2p.  12950             NaN
#
#           fuel
# 0       Diésel
# 1       Diésel
# 2     Gasolina
# 3       Diésel
# 4       Diésel
# ...        ...
# 4995  Gasolina
# 4996  Gasolina
# 4997    Diésel
# 4998    Diésel
# 4999  Gasolina
#
# [5000 rows x 6 columns]

# %%
# Selecciona una cel·la (fila 3, columna `make`). Per tant només retorna una valor
cotxes.loc[3, 'make']
# Out:
# 'OPEL'

# %% [markdown]
# #### Selecció per condicions (`[]`)

# %% [markdown]
# - Podem seleccionar files que compleixin una certa condició. Li passem al DataFrame una sèrie de booleans o una condició lògica que retorni un booleà.
#
# - Podem combinar diferents condicions amb & (operador i lògic) i | (operador o lògic)

# %%
# Seleccionem els cotxes que només siguin de la marca BMW
cotxes[cotxes.make == "BMW"]
# es transforma en una sèrie de true/false
# Out:
#                                company make    model  \
# 1     9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 5
# 25    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 26    9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X1
# 36    9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X1
# 50    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# ...                                ...  ...      ...
# 4902  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 4918  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 4937  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 4
# 4972  9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X2
# 4992  9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X3
#
#                            version  price  price_financed      fuel  year  \
# 1                 BMW Serie 5  4p.   1800             NaN    Diésel  2001
# 25    BMW Serie 3 320D TOURING 5p.   5480             NaN    Diésel  2006
# 26            BMW X1 sDrive18d 5p.  28990         27790.0    Diésel  2019
# 36            BMW X1 sDrive18d 5p.  26890         25890.0    Diésel  2017
# 50            BMW Serie 3 318d 4p.  16900             NaN    Diésel  2016
# ...                            ...    ...             ...       ...   ...
# 4902      BMW Serie 3 320d E90 4p.  10000             NaN    Diésel  2011
# 4918          BMW Serie 3 320D 4p.  20900         19900.0    Diésel  2017
# 4937          BMW Serie 4 420i 2p.  27500         25900.0  Gasolina  2017
# 4972          BMW X2 sDrive18i 5p.  32900         31700.0  Gasolina  2018
# 4992          BMW X3 sDrive18d 5p.  17800         17800.0    Diésel  2013
#
#          kms  power  doors       shift                            color  \
# 1     205000    NaN    4.0      Manual                            Verde
# 25    197000  163.0    5.0  Automático                             Azul
# 26     15000  150.0    5.0      Manual            668 Schwarz (sÃ³lido)
# 36     37675  150.0    5.0  Automático    A96 MineralweiÃ? (metalizado)
# 50     77000  150.0    4.0  Automático                           Blanco
# ...      ...    ...    ...         ...                              ...
# 4902  130000  184.0    4.0      Manual                     Gris / Plata
# 4918   62000  190.0    4.0  Automático  C10 Mediterranblau (metalizado)
# 4937   50550  184.0    2.0  Automático  Rojo (Cuero Dakota Venetobeige)
# 4972   16000  140.0    5.0  Automático            668 Schwarz (sÃ³lido)
# 4992   63794  143.0    5.0      Manual          300 Alpinweib (sÃ³lido)
#
#       photos is_professional                            dealer  \
# 1          0           False  3F128E570B3A9009D7B52A0523AF43DD
# 25         8            True                       Autos Lliça
# 26        36            True                Hispamóvil - Elche
# 36         4            True       Automóviles Bertolín,  S.L.
# 50         6           False  0BC24D6453CD7013F80F2A3A700AC703
# ...      ...             ...                               ...
# 4902       7           False  3887604BAF266030D74F841135E2BD1D
# 4918       3            True               BMW-MINI Fuenteolid
# 4937      32            True               Automoviles Sanchez
# 4972      21            True                 LURAUTO GUIPUZKOA
# 4992      39            True                      Ocasion Plus
#
#                                  phone    province         publish_date  \
# 1     DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 25                           627063458   Barcelona  2020-12-30 10:52:48
# 26                           661257503    Alicante  2020-12-06 11:31:35
# 36                           628104912    Valencia  2020-12-20 16:32:40
# 50    AAD2B172197F21B5A383AAB456255D13      Huelva  2020-11-11 18:25:08
# ...                                ...         ...                  ...
# 4902  D8E7C80957D635195BC851E9D06012EC   Barcelona  2020-09-17 08:15:57
# 4918                         983950700  Valladolid  2020-12-16 16:59:46
# 4937                         689369472    Zaragoza  2021-01-18 18:55:38
# 4972                         678701463   Guipúzcoa  2020-11-20 16:49:48
# 4992                         876500593    Zaragoza  2020-12-07 13:45:49
#
#               insert_date
# 1     2020-12-26 00:00:00
# 25    2021-01-11 00:00:00
# 26    2020-12-08 00:00:00
# 36    2020-12-27 00:00:00
# 50    2021-01-21 00:00:00
# ...                   ...
# 4902  2020-12-16 00:00:00
# 4918  2021-01-06 00:00:00
# 4937  2021-01-26 00:00:00
# 4972  2020-11-28 00:00:00
# 4992  2020-12-10 00:00:00
#
# [462 rows x 20 columns]

# %%
# Seleccionem els cotxes que siguin de la marca BMW i que el seu preu sigui inferior a 20.000
cotxes[(cotxes.make == "BMW") & (cotxes.price < 20000)]
# Out:
#                                company make    model  \
# 1     9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 5
# 25    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 50    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 69    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Compact
# 85    9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 5
# ...                                ...  ...      ...
# 4875  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 5
# 4882  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 5
# 4883  9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X1
# 4902  9881BCDD5A0AD4733037B3FB25E69C3A  BMW  Serie 3
# 4992  9881BCDD5A0AD4733037B3FB25E69C3A  BMW       X3
#
#                             version  price  price_financed      fuel  year  \
# 1                  BMW Serie 5  4p.   1800             NaN    Diésel  2001
# 25     BMW Serie 3 320D TOURING 5p.   5480             NaN    Diésel  2006
# 50             BMW Serie 3 318d 4p.  16900             NaN    Diésel  2016
# 69    BMW Compact 318ti Compact 3p.   1500             NaN  Gasolina  2001
# 85                              BMW   8500             NaN    Diésel  2008
# ...                             ...    ...             ...       ...   ...
# 4875           BMW Serie 5 525D 4p.   7950             NaN    Diésel  2008
# 4882                            BMW   8000             NaN  Gasolina  2003
# 4883      BMW X1 xDrive20d Auto 5p.  12300         12300.0    Diésel  2010
# 4902       BMW Serie 3 320d E90 4p.  10000             NaN    Diésel  2011
# 4992           BMW X3 sDrive18d 5p.  17800         17800.0    Diésel  2013
#
#          kms  power  doors       shift                    color  photos  \
# 1     205000    NaN    4.0      Manual                    Verde       0
# 25    197000  163.0    5.0  Automático                     Azul       8
# 50     77000  150.0    4.0  Automático                   Blanco       6
# 69    215000  143.0    3.0      Manual             Gris / Plata       9
# 85    260000    NaN    5.0      Manual                     Azul      10
# ...      ...    ...    ...         ...                      ...     ...
# 4875  168000  197.0    4.0  Automático                    Verde       7
# 4882  245000    NaN    5.0  Automático                     Azul       4
# 4883  145000  177.0    5.0  Automático                    Beige       8
# 4902  130000  184.0    4.0      Manual             Gris / Plata       7
# 4992   63794  143.0    5.0      Manual  300 Alpinweib (sÃ³lido)      39
#
#      is_professional                            dealer  \
# 1              False  3F128E570B3A9009D7B52A0523AF43DD
# 25              True                       Autos Lliça
# 50             False  0BC24D6453CD7013F80F2A3A700AC703
# 69             False  A10E3F4FB2A23195394CC12700574357
# 85             False  09F96867A8DC816A021FD861F200ABEF
# ...              ...                               ...
# 4875           False  442B0F6448F8BF0EDAA69F58EFE042C6
# 4882           False  58D72E8E4929313BDBA8DC247EF3AA5F
# 4883            True                          WANNAUTO
# 4902           False  3887604BAF266030D74F841135E2BD1D
# 4992            True                      Ocasion Plus
#
#                                  phone    province         publish_date  \
# 1     DBB2949B54A306BA299A791B860EEBF6   Tarragona  2020-12-14 07:02:22
# 25                           627063458   Barcelona  2020-12-30 10:52:48
# 50    AAD2B172197F21B5A383AAB456255D13      Huelva  2020-11-11 18:25:08
# 69    EF996A408AB79ACECED90F378B19C012   Barcelona  2020-12-06 19:40:53
# 85    FA9225DA2E558BAF7BF4905F2A434DA5   Barcelona  2020-12-29 16:40:51
# ...                                ...         ...                  ...
# 4875  9D839816C4E41F19737C1358D2457ED7      Madrid  2020-11-24 10:16:55
# 4882  DD8A708D84154F13437851253387EA49      Madrid  2021-01-05 16:56:13
# 4883                         623023878  Pontevedra  2020-10-01 13:24:35
# 4902  D8E7C80957D635195BC851E9D06012EC   Barcelona  2020-09-17 08:15:57
# 4992                         876500593    Zaragoza  2020-12-07 13:45:49
#
#               insert_date
# 1     2020-12-26 00:00:00
# 25    2021-01-11 00:00:00
# 50    2021-01-21 00:00:00
# 69    2020-12-10 00:00:00
# 85    2021-01-26 00:00:00
# ...                   ...
# 4875  2021-01-21 00:00:00
# 4882  2021-01-24 00:00:00
# 4883  2020-12-24 00:00:00
# 4902  2020-12-16 00:00:00
# 4992  2020-12-10 00:00:00
#
# [299 rows x 20 columns]

# %%
# Seleccionem els cotxes que siguin de la marca BMW o SEAT
cotxes[(cotxes.make == "BMW") | (cotxes.make == "SEAT")]
# Out:
#                                company  make    model  \
# 1     9881BCDD5A0AD4733037B3FB25E69C3A   BMW  Serie 5
# 16    9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ateca
# 21    9881BCDD5A0AD4733037B3FB25E69C3A  SEAT  Córdoba
# 25    9881BCDD5A0AD4733037B3FB25E69C3A   BMW  Serie 3
# 26    9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X1
# ...                                ...   ...      ...
# 4969  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ibiza
# 4972  9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X2
# 4979  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT     León
# 4992  9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X3
# 4994  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ibiza
#
#                                                version  price  price_financed  \
# 1                                     BMW Serie 5  4p.   1800             NaN
# 16    SEAT Ateca 1.0 TSI 85kW 115CV StSp Style Eco 5p.  20900         20900.0
# 21                                   SEAT Cordoba  5p.   1600             NaN
# 25                        BMW Serie 3 320D TOURING 5p.   5480             NaN
# 26                                BMW X1 sDrive18d 5p.  28990         27790.0
# ...                                                ...    ...             ...
# 4969             SEAT Ibiza 1.2 TSI 85cv Reference 5p.   8090          7390.0
# 4972                              BMW X2 sDrive18i 5p.  32900         31700.0
# 4979                 SEAT Leon 1.9 TDi 110CV SIGNA 5p.   1500             NaN
# 4992                              BMW X3 sDrive18d 5p.  17800         17800.0
# 4994         SEAT Ibiza 1.0 EcoTSI 70kW 95CV Style 5p.  10600          9800.0
#
#           fuel  year     kms  power  doors       shift  \
# 1       Diésel  2001  205000    NaN    4.0      Manual
# 16    Gasolina  2019   21212  115.0    5.0      Manual
# 21    Gasolina  2005  220000    NaN    5.0      Manual
# 25      Diésel  2006  197000  163.0    5.0  Automático
# 26      Diésel  2019   15000  150.0    5.0      Manual
# ...        ...   ...     ...    ...    ...         ...
# 4969  Gasolina  2014   44244   85.0    5.0      Manual
# 4972  Gasolina  2018   16000  140.0    5.0  Automático
# 4979    Diésel  2003  250000  110.0    5.0      Manual
# 4992    Diésel  2013   63794  143.0    5.0      Manual
# 4994  Gasolina  2018   59900    NaN    5.0      Manual
#
#                            color  photos is_professional  \
# 1                          Verde       0           False
# 16    Gris / Plata (Gris Rodium)      20            True
# 21                          Azul       8           False
# 25                          Azul       8            True
# 26         668 Schwarz (sÃ³lido)      36            True
# ...                          ...     ...             ...
# 4969                       Negro      35            True
# 4972       668 Schwarz (sÃ³lido)      21            True
# 4979                Gris / Plata       7            True
# 4992     300 Alpinweib (sÃ³lido)      39            True
# 4994                        None      25            True
#
#                                       dealer  \
# 1           3F128E570B3A9009D7B52A0523AF43DD
# 16    Seat Gines Huertas Cervantes Cartagena
# 21          DF8D2684A1B0F1E7AE5A815B7EAA23BA
# 25                               Autos Lliça
# 26                        Hispamóvil - Elche
# ...                                      ...
# 4969                       Flexicar Rivas II
# 4972                       LURAUTO GUIPUZKOA
# 4979                              Car Fusion
# 4992                            Ocasion Plus
# 4994                           Auto Seleccio
#
#                                  phone   province         publish_date  \
# 1     DBB2949B54A306BA299A791B860EEBF6  Tarragona  2020-12-14 07:02:22
# 16                           868205146     Murcia  2020-11-22 16:18:41
# 21    D8BCADD80BED7A6F31C7ACEE768DFF50    Vizcaya  2020-12-17 08:26:43
# 25                           627063458  Barcelona  2020-12-30 10:52:48
# 26                           661257503   Alicante  2020-12-06 11:31:35
# ...                                ...        ...                  ...
# 4969                         910605222     Madrid  2021-01-05 11:02:40
# 4972                         678701463  Guipúzcoa  2020-11-20 16:49:48
# 4979                         688269748     Murcia  2020-12-10 14:20:30
# 4992                         876500593   Zaragoza  2020-12-07 13:45:49
# 4994                         663838373   Valencia  2021-01-15 12:54:40
#
#               insert_date
# 1     2020-12-26 00:00:00
# 16    2020-11-29 00:00:00
# 21    2020-12-19 00:00:00
# 25    2021-01-11 00:00:00
# 26    2020-12-08 00:00:00
# ...                   ...
# 4969  2021-01-18 00:00:00
# 4972  2020-11-28 00:00:00
# 4979  2020-12-19 00:00:00
# 4992  2020-12-10 00:00:00
# 4994  2021-01-22 00:00:00
#
# [720 rows x 20 columns]

# %% [markdown]
# #### selector isin()
#
# A través del selector *isin()* podem seleccionar dades els valor del qual es troba dins d'una llista.

# %%
# Selecciona els cotxes que siguin de la marca BMW i SEAT
cotxes[cotxes.make.isin(['BMW', 'SEAT'])]
# Out:
#                                company  make    model  \
# 1     9881BCDD5A0AD4733037B3FB25E69C3A   BMW  Serie 5
# 16    9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ateca
# 21    9881BCDD5A0AD4733037B3FB25E69C3A  SEAT  Córdoba
# 25    9881BCDD5A0AD4733037B3FB25E69C3A   BMW  Serie 3
# 26    9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X1
# ...                                ...   ...      ...
# 4969  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ibiza
# 4972  9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X2
# 4979  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT     León
# 4992  9881BCDD5A0AD4733037B3FB25E69C3A   BMW       X3
# 4994  9881BCDD5A0AD4733037B3FB25E69C3A  SEAT    Ibiza
#
#                                                version  price  price_financed  \
# 1                                     BMW Serie 5  4p.   1800             NaN
# 16    SEAT Ateca 1.0 TSI 85kW 115CV StSp Style Eco 5p.  20900         20900.0
# 21                                   SEAT Cordoba  5p.   1600             NaN
# 25                        BMW Serie 3 320D TOURING 5p.   5480             NaN
# 26                                BMW X1 sDrive18d 5p.  28990         27790.0
# ...                                                ...    ...             ...
# 4969             SEAT Ibiza 1.2 TSI 85cv Reference 5p.   8090          7390.0
# 4972                              BMW X2 sDrive18i 5p.  32900         31700.0
# 4979                 SEAT Leon 1.9 TDi 110CV SIGNA 5p.   1500             NaN
# 4992                              BMW X3 sDrive18d 5p.  17800         17800.0
# 4994         SEAT Ibiza 1.0 EcoTSI 70kW 95CV Style 5p.  10600          9800.0
#
#           fuel  year     kms  power  doors       shift  \
# 1       Diésel  2001  205000    NaN    4.0      Manual
# 16    Gasolina  2019   21212  115.0    5.0      Manual
# 21    Gasolina  2005  220000    NaN    5.0      Manual
# 25      Diésel  2006  197000  163.0    5.0  Automático
# 26      Diésel  2019   15000  150.0    5.0      Manual
# ...        ...   ...     ...    ...    ...         ...
# 4969  Gasolina  2014   44244   85.0    5.0      Manual
# 4972  Gasolina  2018   16000  140.0    5.0  Automático
# 4979    Diésel  2003  250000  110.0    5.0      Manual
# 4992    Diésel  2013   63794  143.0    5.0      Manual
# 4994  Gasolina  2018   59900    NaN    5.0      Manual
#
#                            color  photos is_professional  \
# 1                          Verde       0           False
# 16    Gris / Plata (Gris Rodium)      20            True
# 21                          Azul       8           False
# 25                          Azul       8            True
# 26         668 Schwarz (sÃ³lido)      36            True
# ...                          ...     ...             ...
# 4969                       Negro      35            True
# 4972       668 Schwarz (sÃ³lido)      21            True
# 4979                Gris / Plata       7            True
# 4992     300 Alpinweib (sÃ³lido)      39            True
# 4994                        None      25            True
#
#                                       dealer  \
# 1           3F128E570B3A9009D7B52A0523AF43DD
# 16    Seat Gines Huertas Cervantes Cartagena
# 21          DF8D2684A1B0F1E7AE5A815B7EAA23BA
# 25                               Autos Lliça
# 26                        Hispamóvil - Elche
# ...                                      ...
# 4969                       Flexicar Rivas II
# 4972                       LURAUTO GUIPUZKOA
# 4979                              Car Fusion
# 4992                            Ocasion Plus
# 4994                           Auto Seleccio
#
#                                  phone   province         publish_date  \
# 1     DBB2949B54A306BA299A791B860EEBF6  Tarragona  2020-12-14 07:02:22
# 16                           868205146     Murcia  2020-11-22 16:18:41
# 21    D8BCADD80BED7A6F31C7ACEE768DFF50    Vizcaya  2020-12-17 08:26:43
# 25                           627063458  Barcelona  2020-12-30 10:52:48
# 26                           661257503   Alicante  2020-12-06 11:31:35
# ...                                ...        ...                  ...
# 4969                         910605222     Madrid  2021-01-05 11:02:40
# 4972                         678701463  Guipúzcoa  2020-11-20 16:49:48
# 4979                         688269748     Murcia  2020-12-10 14:20:30
# 4992                         876500593   Zaragoza  2020-12-07 13:45:49
# 4994                         663838373   Valencia  2021-01-15 12:54:40
#
#               insert_date
# 1     2020-12-26 00:00:00
# 16    2020-11-29 00:00:00
# 21    2020-12-19 00:00:00
# 25    2021-01-11 00:00:00
# 26    2020-12-08 00:00:00
# ...                   ...
# 4969  2021-01-18 00:00:00
# 4972  2020-11-28 00:00:00
# 4979  2020-12-19 00:00:00
# 4992  2020-12-10 00:00:00
# 4994  2021-01-22 00:00:00
#
# [720 rows x 20 columns]

# %% [markdown]
# #### selectors isnull()/notisnull()
#
# Amb aquest selectors podem obtenir aquelles dades que són o no buides (NaN).
# - isna() i notna() són mètodes equivalents

# %%
# Seleccionem els cotxes que no tinguin valor en el camp power
cotxes[cotxes.power.isnull()]
# Out:
#                                company           make     model  \
# 1     9881BCDD5A0AD4733037B3FB25E69C3A            BMW   Serie 5
# 3     9881BCDD5A0AD4733037B3FB25E69C3A           OPEL     Astra
# 5     9881BCDD5A0AD4733037B3FB25E69C3A           OPEL    Zafira
# 7     9881BCDD5A0AD4733037B3FB25E69C3A     VOLKSWAGEN      Polo
# 9     9881BCDD5A0AD4733037B3FB25E69C3A           FORD     Focus
# ...                                ...            ...       ...
# 4939  9881BCDD5A0AD4733037B3FB25E69C3A            KIA  Sportage
# 4948  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL     Astra
# 4974  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ       280
# 4994  9881BCDD5A0AD4733037B3FB25E69C3A           SEAT     Ibiza
# 4997  9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT   Partner
#
#                                         version  price  price_financed  \
# 1                              BMW Serie 5  4p.   1800             NaN
# 3                               OPEL Astra  3p.   5550             NaN
# 5                              OPEL Zafira  5p.   1000             NaN
# 7                          VOLKSWAGEN Polo  5p.   6150             NaN
# 9                               FORD Focus  3p.    700             NaN
# ...                                         ...    ...             ...
# 4939                          KIA Sportage  5p.   3000             NaN
# 4948                                       OPEL   3000             NaN
# 4974                     MERCEDES-BENZ 280  5p.   5500             NaN
# 4994  SEAT Ibiza 1.0 EcoTSI 70kW 95CV Style 5p.  10600          9800.0
# 4997                       PEUGEOT Partner  5p.   6200             NaN
#
#           fuel  year     kms  power  doors   shift         color  photos  \
# 1       Diésel  2001  205000    NaN    4.0  Manual         Verde       0
# 3       Diésel  2009  137000    NaN    3.0  Manual          Rojo       0
# 5       Diésel  2002  400000    NaN    5.0  Manual  Gris / Plata       0
# 7       Diésel  2010  130000    NaN    5.0  Manual  Gris / Plata       0
# 9     Gasolina  2001  256000    NaN    3.0  Manual         Negro       0
# ...        ...   ...     ...    ...    ...     ...           ...     ...
# 4939    Diésel  2005  210000    NaN    5.0  Manual          Rojo       4
# 4948    Diésel  2008  205000    NaN    5.0  Manual         Negro       9
# 4974  Gasolina  1993  110000    NaN    5.0  Manual  Gris / Plata       9
# 4994  Gasolina  2018   59900    NaN    5.0  Manual          None      25
# 4997    Diésel  2012  125000    NaN    5.0  Manual        Blanco       0
#
#      is_professional                            dealer  \
# 1              False  3F128E570B3A9009D7B52A0523AF43DD
# 3              False  22003DEA67E7C5BE6022A29E677668BC
# 5              False  BC2AB28E4CDA984CA76646874371E864
# 7              False  E30470AE2226896865B9C6B56A0F85D5
# 9              False  AAE039D6AA239CFC121357A825210FA3
# ...              ...                               ...
# 4939           False  B8B9DA1A5687243261E3C0D1010FDEED
# 4948           False  E5DEE84F405B9366F44FEEF46DF9704D
# 4974           False  E7E76548A676A2E8FC26D5566062B501
# 4994            True                     Auto Seleccio
# 4997           False  92EAF3719159C372F3D50337E0A14F57
#
#                                  phone   province         publish_date  \
# 1     DBB2949B54A306BA299A791B860EEBF6  Tarragona  2020-12-14 07:02:22
# 3     67990DA67E557C1D0C1B6D1DB731938C  Barcelona  2020-11-21 16:37:13
# 5     75793CB4F71AC1B3C89CF649FFC18C56     Lleida  2020-11-24 16:34:59
# 7     749DB3796A64D10CD64E203A8ECB24C3   Valencia  2020-11-04 15:15:53
# 9     4BC3B4EACC477103EBBFB4131C45534C  Barcelona  2020-10-23 08:42:20
# ...                                ...        ...                  ...
# 4939  F13649BDDF2225102DF0086776569039   Alicante  2020-12-06 14:24:02
# 4948  5791F0D99D1F207533BF6FEC6E5C073E  Tarragona  2020-12-07 20:51:46
# 4974  4F300A557F4883631BAAA4A1CB374604  Barcelona  2021-01-14 09:39:38
# 4994                         663838373   Valencia  2021-01-15 12:54:40
# 4997  A31DAA15140D41FD522BC3DF2341D5A1    Sevilla  2020-10-10 05:51:41
#
#               insert_date
# 1     2020-12-26 00:00:00
# 3     2020-11-24 00:00:00
# 5     2021-01-13 00:00:00
# 7     2020-11-28 00:00:00
# 9     2020-12-11 00:00:00
# ...                   ...
# 4939  2020-12-27 00:00:00
# 4948  2021-01-21 00:00:00
# 4974  2021-01-19 00:00:00
# 4994  2021-01-22 00:00:00
# 4997  2020-12-16 00:00:00
#
# [946 rows x 20 columns]

# %%
# comparem amb isna()
all(cotxes[cotxes.isnull()] == cotxes[cotxes.isna()])
# Out:
# True

# %%
# Seleccionem els cotxes que tinguin valor en el camp power
cotxes[cotxes.power.notnull()]
# Out:
#                                company           make      model  \
# 0     9881BCDD5A0AD4733037B3FB25E69C3A            KIA   Carnival
# 2     9881BCDD5A0AD4733037B3FB25E69C3A           FIAT        500
# 4     9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ    Clase C
# 6     9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT       3008
# 8     9881BCDD5A0AD4733037B3FB25E69C3A           OPEL   Insignia
# ...                                ...            ...        ...
# 4993  9881BCDD5A0AD4733037B3FB25E69C3A           AUDI         A4
# 4995  9881BCDD5A0AD4733037B3FB25E69C3A           OPEL      Corsa
# 4996  9881BCDD5A0AD4733037B3FB25E69C3A         TOYOTA      Auris
# 4998  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ  GLC Coupé
# 4999  9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ   Clase SL
#
#                                                 version  price  \
# 0                      KIA Carnival 2.9 CRDi VGT EX 5p.   4860
# 2                  FIAT 500 1.2 8v 51kW 69CV Lounge 3p.   6490
# 4        MERCEDES-BENZ Clase C C 220 CDI AVANTGARDE 4p.  11990
# 6        PEUGEOT 3008 1.2 PURETECH 130 HP ALLURE SS 5p.  25400
# 8     OPEL Insignia ST 2.0 CDTI ecoFLEX SS 140 CV Se...   8200
# ...                                                 ...    ...
# 4993              AUDI A4 2.0 TDI 150cv multitronic 4p.  16500
# 4995             OPEL Corsa 1.4 66kW 90CV Selective 5p.  10200
# 4996    TOYOTA Auris 1.2 120T Active Touring Sports 5p.   7650
# 4998       MERCEDES-BENZ GLC Coupe GLC 220 d 4MATIC 5p.  49900
# 4999                  MERCEDES-BENZ Clase SL SL 500 2p.  12950
#
#       price_financed      fuel  year     kms  power  doors       shift  \
# 0             4860.0    Diésel  2007  221000  185.0    5.0      Manual
# 2             6490.0  Gasolina  2017   75000   69.0    3.0      Manual
# 4            11490.0    Diésel  2008   95000  170.0    4.0  Automático
# 6            23400.0  Gasolina  2020       0  130.0    5.0      Manual
# 8                NaN    Diésel  2015  119000  140.0    5.0      Manual
# ...              ...       ...   ...     ...    ...    ...         ...
# 4993             NaN    Diésel  2014  128000  150.0    4.0  Automático
# 4995          9400.0  Gasolina  2018   18318   90.0    5.0      Manual
# 4996             NaN  Gasolina  2016  157000  116.0    5.0      Manual
# 4998         48000.0    Diésel  2019      15  170.0    5.0  Automático
# 4999             NaN  Gasolina  2003  129000  306.0    2.0  Automático
#
#                   color  photos is_professional  \
# 0     Beige (champagne)       8            True
# 2                 Negro       7            True
# 4          Gris / Plata      21            True
# 6                Blanco       9            True
# 8                Blanco       6           False
# ...                 ...     ...             ...
# 4993              Negro      20           False
# 4995    Blanco (Alpino)      32            True
# 4996               Azul       5           False
# 4998       Gris / Plata      11            True
# 4999              Negro      30            True
#
#                                 dealer                             phone  \
# 0                             VM Motor                         928493782
# 2                     LAS PALMAS MOTOR                         653895468
# 4                          Autos Lipiz                         646179040
# 6                       Peugeot Beycar                         681167053
# 8     177DACB14B34103960EC27BA29BD686B  4658AA3778BC282BF1CD28EF70287566
# ...                                ...                               ...
# 4993  63FB1088241B0ACDD7987AF0C1F4F7E6  69E12C0BBB06F9AD05BACE575F368AD3
# 4995                     Vara de Quart                         689851902
# 4996  9448B9C35DDD44F451DC88E988CC3A03  67ABDCB290BF2A7CA8D3E84C9007BF9A
# 4998             Autocas Mercedes Benz                         964222200
# 4999                          Autofesa                         910380569
#
#         province         publish_date          insert_date
# 0     Las Palmas  2020-12-22 13:28:36  2020-12-25 00:00:00
# 2     Las Palmas  2020-11-20 18:30:00  2020-12-08 00:00:00
# 4         Madrid  2020-11-05 19:09:27  2020-12-01 00:00:00
# 6     Valladolid  2020-12-17 09:20:50  2021-01-02 00:00:00
# 8     Valladolid  2020-12-16 13:37:39  2020-12-26 00:00:00
# ...          ...                  ...                  ...
# 4993    Alicante  2020-11-16 16:41:56  2020-12-01 00:00:00
# 4995    Valencia  2020-11-23 16:24:28  2020-11-26 00:00:00
# 4996   Tarragona  2020-11-10 15:27:32  2021-01-10 00:00:00
# 4998   Castellón  2020-11-20 09:43:44  2020-11-28 00:00:00
# 4999      Madrid  2021-01-19 09:40:55  2021-01-20 00:00:00
#
# [4054 rows x 20 columns]

# %%
# comparem amb notna()
all(cotxes[cotxes.notnull()] == cotxes[cotxes.notna()])
# Out:
# True

# %% [markdown]
# **Important**: Podem combinar les propietats anteriors per fer seleccions més complexes

# %%
# De tots els cotxes BMW i que el seu preu sigui inferior a 20.000 retornem només la columna `company` (companyia)
cotxes[(cotxes.make == 'BMW') & (cotxes.price < 20000)].company
# Out:
# 1       9881BCDD5A0AD4733037B3FB25E69C3A
# 25      9881BCDD5A0AD4733037B3FB25E69C3A
# 50      9881BCDD5A0AD4733037B3FB25E69C3A
# 69      9881BCDD5A0AD4733037B3FB25E69C3A
# 85      9881BCDD5A0AD4733037B3FB25E69C3A
#                       ...
# 4875    9881BCDD5A0AD4733037B3FB25E69C3A
# 4882    9881BCDD5A0AD4733037B3FB25E69C3A
# 4883    9881BCDD5A0AD4733037B3FB25E69C3A
# 4902    9881BCDD5A0AD4733037B3FB25E69C3A
# 4992    9881BCDD5A0AD4733037B3FB25E69C3A
# Name: company, Length: 299, dtype: object

# %% [markdown]
# #### Ordenació
#
# Podem ordenar un DataFrame per una o diferent columnes mitjanánt el mètode `sort_values`

# %%
# Ordenem els cotxes per preu de forma ascendent
cotxes.sort_values('price', ascending = True)
# Out:
#                                company           make         model  \
# 3369  9881BCDD5A0AD4733037B3FB25E69C3A        RENAULT  Grand Espace
# 965   9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT       Partner
# 2945  9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT           306
# 3918  9881BCDD5A0AD4733037B3FB25E69C3A     VOLKSWAGEN          Golf
# 214   9881BCDD5A0AD4733037B3FB25E69C3A        RENAULT   Clio Campus
# ...                                ...            ...           ...
# 2994  9881BCDD5A0AD4733037B3FB25E69C3A       MASERATI    GranCabrio
# 307   9881BCDD5A0AD4733037B3FB25E69C3A         NISSAN          GT-R
# 4179  9881BCDD5A0AD4733037B3FB25E69C3A        FERRARI           488
# 492   9881BCDD5A0AD4733037B3FB25E69C3A        FERRARI           488
# 666   9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ       Clase G
#
#                                               version   price  price_financed  \
# 3369                        RENAULT Grand Espace  5p.     300             NaN
# 965                              PEUGEOT Partner  5p.     300             NaN
# 2945                                 PEUGEOT 306  5p.     300             NaN
# 3918                    VOLKSWAGEN Golf 1.9TDI GT 3p.     300             NaN
# 214                          RENAULT Clio Campus  3p.     300             NaN
# ...                                               ...     ...             ...
# 2994     MASERATI GranCabrio 4.7 V8 MC Automatico 2p.  169000             NaN
# 307   NISSAN GTR 3.8G V6 441 kW 600 CV 2018 NISMO 2p.  178000        175000.0
# 4179                          FERRARI 488 GTB DCT 2p.  179900             NaN
# 492                               FERRARI 488 GTB 2p.  199995        199995.0
# 666        MERCEDES-BENZ Clase G MercedesAMG G 63 5p.  319900             NaN
#
#           fuel  year     kms  power  doors       shift  \
# 3369    Diésel  2004  308000    NaN    5.0  Automático
# 965     Diésel  2001  300000    NaN    5.0      Manual
# 2945    Diésel  2001  250000    NaN    5.0      Manual
# 3918    Diésel  1996  330000  110.0    3.0      Manual
# 214   Gasolina  1997  280000    NaN    3.0      Manual
# ...        ...   ...     ...    ...    ...         ...
# 2994  Gasolina  2018      25  460.0    2.0  Automático
# 307   Gasolina  2018    8800  600.0    2.0  Automático
# 4179  Gasolina  2017   29000  670.0    2.0  Automático
# 492   Gasolina  2016   21000  670.0    2.0  Automático
# 666   Gasolina  2020     950  585.0    5.0  Automático
#
#                                  color  photos is_professional  \
# 3369                      Gris / Plata       0           False
# 965                             Blanco       0           False
# 2945                            Blanco       0           False
# 3918                            Blanco       5           False
# 214                             Blanco       0           False
# ...                                ...     ...             ...
# 2994                            Blanco      33            True
# 307                  Blanco (NACARADO)      11            True
# 4179  (( TODO EN FERRARI, IMPECABLE ))      54            True
# 492                             Blanco      24            True
# 666                             Blanco      18            True
#
#                                 dealer                             phone  \
# 3369  1CC477616BB182E87EC7285BFBF8C34B  0F15D893FAF27C539C5A17F318192695
# 965   886B47377FB31499B423AAD678A44E12  624E82E25874F6F7272D58ACC36F7570
# 2945  E9829608DD90FF6B8BF7CB50746EAE78  63C7B71B9870174258DD8AA09065EB84
# 3918  DC9E99873BF9292F1C365F363E8D6BBF  2BA008A802E63C0795627E3C3AC10025
# 214   1AD2F57CFFFCF3CEB33A19520334CC4C  8AEBD8EA72630910A1F6F75113238490
# ...                                ...                               ...
# 2994                     GJ AUTOMOTIVE                         645038369
# 307               Premium Cars Sevilla                         687681055
# 4179                      Luxury Motor                         917864520
# 492                     konzept españa                         669625871
# 666              Driver Cars Barcelona                         938444882
#
#        province         publish_date          insert_date
# 3369    Navarra  2020-09-14 19:00:20  2020-12-11 00:00:00
# 965       Cádiz  2020-08-17 14:42:51  2020-11-24 00:00:00
# 2945  Guipúzcoa  2020-11-18 10:49:56  2020-11-26 00:00:00
# 3918  Barcelona  2020-12-31 09:29:08  2021-01-04 00:00:00
# 214    Tenerife  2020-12-06 15:37:20  2021-01-26 00:00:00
# ...         ...                  ...                  ...
# 2994     Burgos  2020-10-27 12:55:55  2021-01-01 00:00:00
# 307     Sevilla  2020-11-12 12:08:16  2020-12-14 00:00:00
# 4179     Madrid  2020-12-31 12:12:40  2021-01-01 00:00:00
# 492     Badajoz  2020-12-18 11:47:05  2021-01-15 00:00:00
# 666   Barcelona  2020-11-13 11:31:03  2020-12-06 00:00:00
#
# [5000 rows x 20 columns]

# %%
# Ordenem els cotxes per preu de forma ascendent i any de forma descendent
cotxes.sort_values(['price','year'], ascending = [True,False])
# Out:
#                                company           make         model  \
# 3369  9881BCDD5A0AD4733037B3FB25E69C3A        RENAULT  Grand Espace
# 4154  9881BCDD5A0AD4733037B3FB25E69C3A            BMW       Serie 3
# 965   9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT       Partner
# 2945  9881BCDD5A0AD4733037B3FB25E69C3A        PEUGEOT           306
# 214   9881BCDD5A0AD4733037B3FB25E69C3A        RENAULT   Clio Campus
# ...                                ...            ...           ...
# 2994  9881BCDD5A0AD4733037B3FB25E69C3A       MASERATI    GranCabrio
# 307   9881BCDD5A0AD4733037B3FB25E69C3A         NISSAN          GT-R
# 4179  9881BCDD5A0AD4733037B3FB25E69C3A        FERRARI           488
# 492   9881BCDD5A0AD4733037B3FB25E69C3A        FERRARI           488
# 666   9881BCDD5A0AD4733037B3FB25E69C3A  MERCEDES-BENZ       Clase G
#
#                                               version   price  price_financed  \
# 3369                        RENAULT Grand Espace  5p.     300             NaN
# 4154                                 BMW Serie 3  5p.     300             NaN
# 965                              PEUGEOT Partner  5p.     300             NaN
# 2945                                 PEUGEOT 306  5p.     300             NaN
# 214                          RENAULT Clio Campus  3p.     300             NaN
# ...                                               ...     ...             ...
# 2994     MASERATI GranCabrio 4.7 V8 MC Automatico 2p.  169000             NaN
# 307   NISSAN GTR 3.8G V6 441 kW 600 CV 2018 NISMO 2p.  178000        175000.0
# 4179                          FERRARI 488 GTB DCT 2p.  179900             NaN
# 492                               FERRARI 488 GTB 2p.  199995        199995.0
# 666        MERCEDES-BENZ Clase G MercedesAMG G 63 5p.  319900             NaN
#
#           fuel  year     kms  power  doors       shift  \
# 3369    Diésel  2004  308000    NaN    5.0  Automático
# 4154    Diésel  2002  220000    NaN    5.0      Manual
# 965     Diésel  2001  300000    NaN    5.0      Manual
# 2945    Diésel  2001  250000    NaN    5.0      Manual
# 214   Gasolina  1997  280000    NaN    3.0      Manual
# ...        ...   ...     ...    ...    ...         ...
# 2994  Gasolina  2018      25  460.0    2.0  Automático
# 307   Gasolina  2018    8800  600.0    2.0  Automático
# 4179  Gasolina  2017   29000  670.0    2.0  Automático
# 492   Gasolina  2016   21000  670.0    2.0  Automático
# 666   Gasolina  2020     950  585.0    5.0  Automático
#
#                                  color  photos is_professional  \
# 3369                      Gris / Plata       0           False
# 4154                      Gris / Plata       0           False
# 965                             Blanco       0           False
# 2945                            Blanco       0           False
# 214                             Blanco       0           False
# ...                                ...     ...             ...
# 2994                            Blanco      33            True
# 307                  Blanco (NACARADO)      11            True
# 4179  (( TODO EN FERRARI, IMPECABLE ))      54            True
# 492                             Blanco      24            True
# 666                             Blanco      18            True
#
#                                 dealer                             phone  \
# 3369  1CC477616BB182E87EC7285BFBF8C34B  0F15D893FAF27C539C5A17F318192695
# 4154  AE1D4B431EAD52E5EE1788010E8EC110  84623CD5C90A43471DEC343064DA5C89
# 965   886B47377FB31499B423AAD678A44E12  624E82E25874F6F7272D58ACC36F7570
# 2945  E9829608DD90FF6B8BF7CB50746EAE78  63C7B71B9870174258DD8AA09065EB84
# 214   1AD2F57CFFFCF3CEB33A19520334CC4C  8AEBD8EA72630910A1F6F75113238490
# ...                                ...                               ...
# 2994                     GJ AUTOMOTIVE                         645038369
# 307               Premium Cars Sevilla                         687681055
# 4179                      Luxury Motor                         917864520
# 492                     konzept españa                         669625871
# 666              Driver Cars Barcelona                         938444882
#
#        province         publish_date          insert_date
# 3369    Navarra  2020-09-14 19:00:20  2020-12-11 00:00:00
# 4154     Madrid  2020-11-25 10:22:57  2021-01-19 00:00:00
# 965       Cádiz  2020-08-17 14:42:51  2020-11-24 00:00:00
# 2945  Guipúzcoa  2020-11-18 10:49:56  2020-11-26 00:00:00
# 214    Tenerife  2020-12-06 15:37:20  2021-01-26 00:00:00
# ...         ...                  ...                  ...
# 2994     Burgos  2020-10-27 12:55:55  2021-01-01 00:00:00
# 307     Sevilla  2020-11-12 12:08:16  2020-12-14 00:00:00
# 4179     Madrid  2020-12-31 12:12:40  2021-01-01 00:00:00
# 492     Badajoz  2020-12-18 11:47:05  2021-01-15 00:00:00
# 666   Barcelona  2020-11-13 11:31:03  2020-12-06 00:00:00
#
# [5000 rows x 20 columns]

# %% [markdown]
# ## Agrupació (Group by)
#
# Moltes vegades ens interessa realtizar una sèrie de funcions d'agregat realtizant una agrupació per un camp concret.
# Això ho aconseguirem mitjançant la funció `groupby` antre altres

# %%
# Si volem buscar el preu mínim de cada marca
cotxes.groupby('make').price.min()
# Out:
# make
# ABARTH           12800
# ALFA ROMEO         700
# ASTON MARTIN     39990
# AUDI               600
# BENTLEY          36990
# BMW                300
# CHEVROLET          500
# CHRYSLER          1000
# CITROEN            650
# DACIA             3790
# DAEWOO             850
# DFSK             26495
# DODGE             2300
# DS               12800
# FERRARI          77000
# FIAT               950
# FORD               500
# GALLOPER           875
# HONDA             1000
# HUMMER           23000
# HYUNDAI           1300
# INFINITI         14490
# ISUZU            10500
# IVECO             3600
# JAGUAR            1000
# JEEP              5500
# KIA               1200
# LADA              1400
# LANCIA            1000
# LAND-ROVER        3200
# LEXUS             4000
# MASERATI         36000
# MAZDA             1000
# MERCEDES-BENZ      500
# MG                 650
# MINI              3300
# MITSUBISHI         670
# NISSAN             850
# OPEL               400
# PEUGEOT            300
# PORSCHE           8490
# RENAULT            300
# ROLLS-ROYCE      26950
# ROVER              550
# SAAB              2590
# SEAT               500
# SKODA              590
# SMART             2300
# SSANGYONG         4000
# SUBARU            4100
# SUZUKI            1100
# TATA              5000
# TESLA            38500
# TOYOTA            1600
# VOLKSWAGEN         300
# VOLVO             1800
# Name: price, dtype: int64

# %%
# si fem un count() per marques ens compta els valors **no nulls** de cada columna/marca
cotxes.groupby('make').count()
# Out:
#                company  model  version  price  price_financed  fuel  year  \
# make
# ABARTH              17     17       17     17               8    17    17
# ALFA ROMEO          33     33       33     33               9    33    33
# ASTON MARTIN         3      3        3      3               1     3     3
# AUDI               351    351      351    351             139   351   351
# BENTLEY              4      4        4      4               0     4     4
# BMW                462    462      462    462             185   462   462
# CHEVROLET           25     25       25     25               8    25    25
# CHRYSLER            12     12       12     12               0    12    12
# CITROEN            288    288      288    288             136   288   288
# DACIA               18     18       18     18              11    18    18
# DAEWOO               3      3        3      3               0     3     3
# DFSK                 2      2        2      2               2     2     2
# DODGE                3      3        3      3               0     3     3
# DS                  16     16       16     16              12    16    16
# FERRARI              6      6        6      6               1     6     6
# FIAT               124    124      124    124              74   124   124
# FORD               306    306      306    306             155   306   306
# GALLOPER             1      1        1      1               0     1     1
# HONDA               47     47       47     47              15    47    47
# HUMMER               1      1        1      1               0     1     1
# HYUNDAI            106    106      106    106              63   106   106
# INFINITI             6      6        6      6               5     6     6
# ISUZU                3      2        3      3               0     2     3
# IVECO                4      4        4      4               0     4     4
# JAGUAR              36     36       36     36              20    36    36
# JEEP                21     21       21     21              13    21    21
# KIA                 96     96       96     96              65    96    96
# LADA                 1      1        1      1               0     1     1
# LANCIA               4      4        4      4               0     4     4
# LAND-ROVER          67     67       67     67              27    67    67
# LEXUS               28     28       28     28              12    26    28
# MASERATI             6      6        6      6               2     6     6
# MAZDA               54     54       54     54              25    54    54
# MERCEDES-BENZ      404    403      404    404             161   401   404
# MG                   2      2        2      2               0     2     2
# MINI                66     66       66     66              25    66    66
# MITSUBISHI          37     37       37     37              19    37    37
# NISSAN             143    143      143    143              74   143   143
# OPEL               298    298      298    298             128   298   298
# PEUGEOT            342    342      342    342             162   342   342
# PORSCHE             42     42       42     42              14    42    42
# RENAULT            346    346      346    346             151   346   346
# ROLLS-ROYCE          2      2        2      2               0     2     2
# ROVER                5      5        5      5               0     5     5
# SAAB                 9      9        9      9               0     9     9
# SEAT               258    257      258    258             116   258   258
# SKODA               70     70       70     70              47    70    70
# SMART               18     18       18     18               6    18    18
# SSANGYONG           17     17       17     17               7    17    17
# SUBARU              13     13       13     13               8    13    13
# SUZUKI              29     29       29     29              17    29    29
# TATA                 1      1        1      1               0     1     1
# TESLA                2      2        2      2               2     2     2
# TOYOTA             156    156      156    156              83   155   156
# VOLKSWAGEN         497    497      497    497             213   497   497
# VOLVO               89     88       89     89              47    88    89
#
#                kms  power  doors  shift  color  photos  is_professional  \
# make
# ABARTH          17     16     17     17     16      17               17
# ALFA ROMEO      33     21     33     33     33      33               33
# ASTON MARTIN     3      3      3      3      3       3                3
# AUDI           351    295    351    350    347     351              351
# BENTLEY          4      4      4      4      4       4                4
# BMW            462    363    461    461    456     462              462
# CHEVROLET       25     19     25     25     25      25               25
# CHRYSLER        12      6     12     12     11      12               12
# CITROEN        288    225    288    287    285     288              288
# DACIA           18     16     18     18     18      18               18
# DAEWOO           3      1      3      3      3       3                3
# DFSK             2      2      2      2      2       2                2
# DODGE            3      3      3      3      3       3                3
# DS              16     16     16     16     16      16               16
# FERRARI          6      6      6      6      6       6                6
# FIAT           124    107    124    124    122     124              124
# FORD           306    235    306    306    302     306              306
# GALLOPER         1      1      1      1      1       1                1
# HONDA           47     32     47     47     46      47               47
# HUMMER           1      1      1      1      1       1                1
# HYUNDAI        106     95    106    106    106     106              106
# INFINITI         6      6      6      6      6       6                6
# ISUZU            3      2      2      2      3       3                3
# IVECO            4      3      4      4      4       4                4
# JAGUAR          36     32     36     35     36      36               36
# JEEP            21     20     21     20     21      21               21
# KIA             96     88     96     96     96      96               96
# LADA             1      1      1      1      1       1                1
# LANCIA           4      3      4      4      4       4                4
# LAND-ROVER      67     62     67     67     67      67               67
# LEXUS           28     24     28     28     28      28               28
# MASERATI         6      6      6      6      6       6                6
# MAZDA           54     41     54     54     54      54               54
# MERCEDES-BENZ  404    337    403    403    403     404              404
# MG               2      1      2      2      2       2                2
# MINI            66     58     66     66     66      66               66
# MITSUBISHI      37     29     37     37     37      37               37
# NISSAN         143    124    143    143    140     143              143
# OPEL           298    229    298    298    295     298              298
# PEUGEOT        342    273    342    340    338     342              342
# PORSCHE         42     41     42     42     42      42               42
# RENAULT        346    267    346    346    340     346              346
# ROLLS-ROYCE      2      2      2      2      2       2                2
# ROVER            5      0      5      5      5       5                5
# SAAB             9      6      9      9      9       9                9
# SEAT           258    190    258    258    252     258              258
# SKODA           70     65     70     70     70      70               70
# SMART           18     17     18     18     18      18               18
# SSANGYONG       17     13     17     17     17      17               17
# SUBARU          13     13     13     13     13      13               13
# SUZUKI          29     26     29     29     28      29               29
# TATA             1      1      1      1      1       1                1
# TESLA            2      2      2      2      2       2                2
# TOYOTA         156    140    156    156    155     156              156
# VOLKSWAGEN     497    387    497    497    487     497              497
# VOLVO           89     78     88     88     88      89               89
#
#                dealer  phone  province  publish_date  insert_date
# make
# ABARTH             17     17        17            17           17
# ALFA ROMEO         33     33        33            33           33
# ASTON MARTIN        3      3         3             3            3
# AUDI              351    351       351           351          351
# BENTLEY             4      4         4             4            4
# BMW               462    462       462           462          462
# CHEVROLET          25     25        25            25           25
# CHRYSLER           12     12        12            12           12
# CITROEN           288    288       288           288          288
# DACIA              18     18        18            18           18
# DAEWOO              3      3         3             3            3
# DFSK                2      2         2             2            2
# DODGE               3      3         3             3            3
# DS                 16     16        16            16           16
# FERRARI             6      6         6             6            6
# FIAT              124    124       124           124          124
# FORD              306    306       306           306          306
# GALLOPER            1      1         1             1            1
# HONDA              47     47        47            47           47
# HUMMER              1      1         1             1            1
# HYUNDAI           106    106       106           106          106
# INFINITI            6      6         6             6            6
# ISUZU               3      3         3             3            3
# IVECO               4      4         4             4            4
# JAGUAR             36     36        36            36           36
# JEEP               21     21        21            21           21
# KIA                96     96        96            96           96
# LADA                1      1         1             1            1
# LANCIA              4      4         4             4            4
# LAND-ROVER         67     67        67            67           67
# LEXUS              28     28        28            28           28
# MASERATI            6      6         6             6            6
# MAZDA              54     54        54            54           54
# MERCEDES-BENZ     404    404       404           404          404
# MG                  2      2         2             2            2
# MINI               66     66        66            66           66
# MITSUBISHI         37     37        37            37           37
# NISSAN            143    143       143           143          143
# OPEL              298    298       298           298          298
# PEUGEOT           342    342       342           342          342
# PORSCHE            42     42        42            42           42
# RENAULT           346    346       346           346          346
# ROLLS-ROYCE         2      2         2             2            2
# ROVER               5      5         5             5            5
# SAAB                9      9         9             9            9
# SEAT              258    258       258           258          258
# SKODA              70     70        70            70           70
# SMART              18     18        18            18           18
# SSANGYONG          17     17        17            17           17
# SUBARU             13     13        13            13           13
# SUZUKI             29     29        29            29           29
# TATA                1      1         1             1            1
# TESLA               2      2         2             2            2
# TOYOTA            156    156       156           156          156
# VOLKSWAGEN        497    497       497           497          497
# VOLVO              89     89        89            89           89

# %% [markdown]
# ##### Exercici
#
# Fixa't que per la marca ALFA ROMEO hi ha alguns vehicles que tenen un valor null a la columna *power*
# Prova de localitzar-los.

# %%
null_power = cotxes[(cotxes.make == "ALFA ROMEO") & (cotxes.power.isna())]
len(null_power)
# Out:
# 12

# %%
# Volem saber quina és la quantitat de vehicles de cada model per cada marca
cotxes.groupby('make').model.value_counts()
# Out:
# make        model
# ABARTH      500                  11
#             500C                  6
# ALFA ROMEO  147                   7
#             Giulietta             6
#             Stelvio               5
#                                  ..
# VOLVO       850                   1
#             Classic               1
#             V60 Cross Country     1
#             V70 XC                1
#             V90                   1
# Name: model, Length: 607, dtype: int64

# %% [markdown]
# Podem agrupar per més d'un camp passant una llista de camps a agrupar.

# %%
# Volem obtenir el preu mínim de cada marca i model.
cotxes.groupby(['make','model']).price.min()
# Out:
# make        model
# ABARTH      500                  12800
#             500C                 13100
# ALFA ROMEO  146                    700
#             147                   2000
#             156                   2500
#                                  ...
# VOLVO       V90 Cross Country    37400
#             XC40                 27700
#             XC60                 10900
#             XC70                  3790
#             XC90                  6999
# Name: price, Length: 607, dtype: int64

# %% [markdown]
# Amb la funció `aggregate()` o `agg()` podem aplicar certes funcions d'agregat (len, min, max, sum, np.mean, np.std, np.median, np.var) i si tenim carregada la llibreria de NumPy millor alhora per treure alguna estadística

# %%
# Podem obtenir estadístics per cada marca
cotxes.groupby('make').price.agg([len, min, max, sum])
# Out:
#                len    min     max      sum
# make
# ABARTH          17  12800   28000   318317
# ALFA ROMEO      33    700   49900   463959
# ASTON MARTIN     3  39990   89000   174890
# AUDI           351    600   81900  6738303
# BENTLEY          4  36990   99900   241790
# BMW            462    300   72500  8358518
# CHEVROLET       25    500   12900   149668
# CHRYSLER        12   1000    7800    39100
# CITROEN        288    650   36995  2620719
# DACIA           18   3790   18000   153902
# DAEWOO           3    850    1800     4450
# DFSK             2  26495   29900    56395
# DODGE            3   2300    7500    13000
# DS              16  12800   53500   412489
# FERRARI          6  77000  199995   787695
# FIAT           124    950   23500  1081000
# FORD           306    500   48900  3173725
# GALLOPER         1    875     875      875
# HONDA           47   1000   34990   429119
# HUMMER           1  23000   23000    23000
# HYUNDAI        106   1300   39900  1420734
# INFINITI         6  14490   23999   114729
# ISUZU            3  10500   49900    74900
# IVECO            4   3600   15730    31130
# JAGUAR          36   1000   59990   901581
# JEEP            21   5500   50500   459186
# KIA             96   1200   47200  1406960
# LADA             1   1400    1400     1400
# LANCIA           4   1000   26900    36599
# LAND-ROVER      67   3200  106680  2276496
# LEXUS           28   4000   68000   658554
# MASERATI         6  36000  169000   509190
# MAZDA           54   1000   30690   738362
# MERCEDES-BENZ  404    500  319900  9726011
# MG               2    650    5500     6150
# MINI            66   3300   33900   894926
# MITSUBISHI      37    670   49999   586023
# NISSAN         143    850  178000  2151799
# OPEL           298    400   40900  2723463
# PEUGEOT        342    300   44000  3730380
# PORSCHE         42   8490  138000  2462817
# RENAULT        346    300   31900  3345030
# ROLLS-ROYCE      2  26950   98000   124950
# ROVER            5    550    1899     5899
# SAAB             9   2590   35000    72975
# SEAT           258    500   38355  2609440
# SKODA           70    590   37500   897884
# SMART           18   2300   21500   159016
# SSANGYONG       17   4000   24800   195278
# SUBARU          13   4100   32700   267579
# SUZUKI          29   1100   26900   352940
# TATA             1   5000    5000     5000
# TESLA            2  38500   45900    84400
# TOYOTA         156   1600   60900  2277703
# VOLKSWAGEN     497    300   55000  6637571
# VOLVO           89   1800   66900  2068890

# %%
# Podem ordenar el resultat anterior per quantitat de vehicles
cotxes.groupby(['make', 'model']).price.agg([len, min, max, sum]).sort_values(by = "len", ascending = False)

# El index és la combinació de les columnes make i model si ho volem canviar és la cel·la de baix
# Out:
#                           len    min    max      sum
# make       model
# VOLKSWAGEN Golf           162    300  42990  1942233
# BMW        Serie 3        148    300  70999  1938617
# SEAT       Ibiza           96    500  21900   562076
# AUDI       A4              94    650  39900  1316643
# RENAULT    Mégane          90    500  29100   777006
# ...                       ...    ...    ...      ...
# NISSAN     Murano           1  16900  16900    16900
#            Patrol GR        1   8950   8950     8950
#            Serena           1   1150   1150     1150
#            Vanette Cargo    1    950    950      950
#            Cabstar          1   2500   2500     2500
#
# [607 rows x 4 columns]

# %% [markdown]
# En els exemples que hem vist anteriorment el resultat s'ha tranformat amb un **multiindex**.
#
# Per tornar a convertir el resultat amb un índex normal cal utilitzar el mètode `reset_index()`

# %%
cotxes.groupby(['make', 'model']).price.agg([len, min, max, sum]).sort_values(by = 'len', ascending = False).reset_index()
# Out:
#            make          model  len    min    max      sum
# 0    VOLKSWAGEN           Golf  162    300  42990  1942233
# 1           BMW        Serie 3  148    300  70999  1938617
# 2          SEAT          Ibiza   96    500  21900   562076
# 3          AUDI             A4   94    650  39900  1316643
# 4       RENAULT         Mégane   90    500  29100   777006
# ..          ...            ...  ...    ...    ...      ...
# 602      NISSAN         Murano    1  16900  16900    16900
# 603      NISSAN      Patrol GR    1   8950   8950     8950
# 604      NISSAN         Serena    1   1150   1150     1150
# 605      NISSAN  Vanette Cargo    1    950    950      950
# 606      NISSAN        Cabstar    1   2500   2500     2500
#
# [607 rows x 6 columns]
