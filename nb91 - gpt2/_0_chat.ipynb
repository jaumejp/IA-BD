# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' 
import tensorflow as tf
# Out:
# 2024-05-22 18:36:28.165868: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 18:36:28.165904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 18:36:28.166438: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-22 18:36:28.582182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Per poder fer el import hem de posar la ruta
# - a: `/home/jaume/miniconda3/envs/entorn/lib/python3.1/site-packages`
# - `sudo nano conda.pth`
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
# Del repositori que hem baixat gpt2.
import gpt2

# %%
gpt2.main("Alan Turing theorized that computers would one day become")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gpt2.main("Alan Turing theorized that computers would one day become")
#
# AttributeError: module 'gpt2' has no attribute 'main'
