# %% [markdown]
# # Naive Bayes classifier for spam filtering

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Dataset from https://archive.ics.uci.edu/ml/datasets/sms+spam+collection

# %%
df = pd.read_csv('../Dades/sms/SMSSpamCollection', header=None, sep='\t', names=['Label', 'SMS'])

# %%
df.head()
# Out:
#   Label                                                SMS
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.Label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: Label, dtype: int64

# %% [markdown]
# ### metodología
#
# 1. Construim un diccionari amb ***totes les paraules (tokens)*** dels missatges que tenim al dataset
#
# 2. Apliquem un classificador naive Bayes:
#     - cada paraula del missatge és una nova font d'informació sobre la possible naturalesa del missatge
#     - implícitament, estem considerant les paraules com variables independents *cosa que òbviament no és certa* (però això ja és la filosofia naive Bayes)
#     - en aquest cas però, cada paraula és una ***realització*** de la mateixa variable estocàstica $X=\text{"incloure paraula en el missatge"}$
#
# 3. Definim dues funcions de versemblança per X:
#     - una ens indica com de versemblant és que s'hagi inclòs una determinada paraula en un missatge NO_SPAM (ham) $P\left(X=\text{'love'}\,|Y=\text{ham}\right)$
#     - una ens indica com de versemblant és que s'hagi inclòs una determinada paraula en un missatge SPAM $P\left(X=\text{'love'}\,|Y=\text{spam}\right)$
#     - les dues funcions de versemblança son ***discretes*** i de ***cardinalitat igual al número de paraules que tenim al diccionari***

# %% [markdown]
# ### preparació de les dades
# - eliminar signes de puntuació
# - passar tot a minúscules
# - separar les paraules (***tokenize***)

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def tokenize(message):
    for p in string.punctuation:
        message = message.replace(p, ' ')
    return message.lower().split()

# %%
# %time
df['sms'] = df.SMS.apply(tokenize)
df.head()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#   Label                                                SMS  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                                  sms
# 0  [go, until, jurong, point, crazy, available, o...
# 1                     [ok, lar, joking, wif, u, oni]
# 2  [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3  [u, dun, say, so, early, hor, u, c, already, t...
# 4  [nah, i, don, t, think, he, goes, to, usf, he,...

# %%
print(df.iloc[100]['SMS'])
print(df.iloc[100]['sms'])
# Out:
# Please don't text me anymore. I have nothing else to say.
# ['please', 'don', 't', 'text', 'me', 'anymore', 'i', 'have', 'nothing', 'else', 'to', 'say']

# %% [markdown]
# ### Hi haurà un gran gruix de paraules són dels dos i un petit seran nomès de un. Seran aquestes petites les que fan decantar la balança.

# %% [markdown]
# ### Split train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(df, test_size = 0.2, random_state = 2873)

# %%
print(X_train.shape)
X_train.head()
# Out:
# (4457, 3)
#      Label                                                SMS  \
# 632    ham                                           Thank u!
# 4343   ham  Ha! I wouldn't say that I just didn't read any...
# 13     ham  I've been searching for the right words to tha...
# 3227   ham  Rose for red,red for blood,blood for heart,hea...
# 4515   ham         Sure, whenever you show the fuck up &gt;:(
#
#                                                     sms
# 632                                          [thank, u]
# 4343  [ha, i, wouldn, t, say, that, i, just, didn, t...
# 13    [i, ve, been, searching, for, the, right, word...
# 3227  [rose, for, red, red, for, blood, blood, for, ...
# 4515     [sure, whenever, you, show, the, fuck, up, gt]

# %%
X_train.Label.value_counts(normalize = True)
# Out:
# ham     0.869195
# spam    0.130805
# Name: Label, dtype: float64

# %%
print(X_test.shape)
X_test.head()
# Out:
# (1115, 3)
#      Label                                                SMS  \
# 4062   ham  Aight I've been set free, think you could text...
# 494    ham                 What class of  &lt;#&gt;  reunion?
# 1396   ham  Thats cool! I am a gentleman and will treat yo...
# 2575  spam  Your next amazing xxx PICSFREE1 video will be ...
# 3120   ham                           Stop knowing me so well!
#
#                                                     sms
# 4062  [aight, i, ve, been, set, free, think, you, co...
# 494                  [what, class, of, lt, gt, reunion]
# 1396  [thats, cool, i, am, a, gentleman, and, will, ...
# 2575  [your, next, amazing, xxx, picsfree1, video, w...
# 3120                      [stop, knowing, me, so, well]

# %% [markdown]
# ### quan mostrejem aleatoriament, el subconjunt, ha de conservar més o menys la mateixa proporció.

# %%
X_test.Label.value_counts(normalize = True)
# Out:
# ham     0.852915
# spam    0.147085
# Name: Label, dtype: float64

# %% [markdown]
# ### get dictionary of words from the train dataset

# %%
# Tenim  una llista amb totes, i mirem quantes n'hi ha i inicialitzem un dict a 0 per aquesta paraula.

# %%
# Totes lesparaules junts
X_train['sms'].sum()
# Out:
# ['thank',
#  'u',
#  'ha',
#  'i',
#  'wouldn',
#  't',
#  'say',
#  'that',
#  'i',
#  'just',
#  'didn',
#  't',
#  'read',
#  'anything',
#  'into',
#  'way',
#  'u',
#  'seemed',
#  'i',
#  'don',
#  't',
#  'like',
#  '2',
#  'be',
#  'judgemental',
#  'i',
#  'save',
#  'that',
#  'for',
#  'fridays',
#  'in',
#  'the',
#  'pub',
#  'i',
#  've',
#  'been',
#  'searching',
#  'for',
#  'the',
#  'right',
#  'words',
#  'to',
#  'thank',
#  'you',
#  'for',
#  'this',
#  'breather',
#  'i',
#  'promise',
#  'i',
#  'wont',
#  'take',
#  'your',
#  'help',
#  'for',
#  'granted',
#  'and',
#  'will',
#  'fulfil',
#  'my',
#  'promise',
#  'you',
#  'have',
#  'been',
#  'wonderful',
#  'and',
#  'a',
#  'blessing',
#  'at',
#  'all',
#  'times',
#  'rose',
#  'for',
#  'red',
#  'red',
#  'for',
#  'blood',
#  'blood',
#  'for',
#  'heart',
#  'heart',
#  'for',
#  'u',
#  'but',
#  'u',
#  'for',
#  'me',
#  'send',
#  'tis',
#  'to',
#  'all',
#  'ur',
#  'friends',
#  'including',
#  'me',
#  'if',
#  'u',
#  'like',
#  'me',
#  'if',
#  'u',
#  'get',
#  'back',
#  '1',
#  'u',
#  'r',
#  'poor',
#  'in',
#  'relation',
#  '2',
#  'u',
#  'need',
#  'some',
#  '1',
#  'to',
#  'support',
#  '3',
#  'u',
#  'r',
#  'frnd',
#  '2',
#  'many',
#  '4',
#  'some1',
#  'luvs',
#  'u',
#  '5',
#  'some1',
#  'is',
#  'praying',
#  'god',
#  'to',
#  'marry',
#  'u',
#  'try',
#  'it',
#  'sure',
#  'whenever',
#  'you',
#  'show',
#  'the',
#  'fuck',
#  'up',
#  'gt',
#  'it',
#  's',
#  'ok',
#  'i',
#  'noe',
#  'u',
#  're',
#  'busy',
#  'but',
#  'i',
#  'm',
#  'really',
#  'too',
#  'bored',
#  'so',
#  'i',
#  'msg',
#  'u',
#  'i',
#  'oso',
#  'dunno',
#  'wat',
#  'colour',
#  'she',
#  'choose',
#  '4',
#  'me',
#  'one',
#  'jay',
#  'wants',
#  'to',
#  'work',
#  'out',
#  'first',
#  'how',
#  's',
#  '4',
#  'sound',
#  'i',
#  'am',
#  'seeking',
#  'a',
#  'lady',
#  'in',
#  'the',
#  'street',
#  'and',
#  'a',
#  'freak',
#  'in',
#  'the',
#  'sheets',
#  'is',
#  'that',
#  'you',
#  'night',
#  'has',
#  'ended',
#  'for',
#  'another',
#  'day',
#  'morning',
#  'has',
#  'come',
#  'in',
#  'a',
#  'special',
#  'way',
#  'may',
#  'you',
#  'smile',
#  'like',
#  'the',
#  'sunny',
#  'rays',
#  'and',
#  'leaves',
#  'your',
#  'worries',
#  'at',
#  'the',
#  'blue',
#  'blue',
#  'bay',
#  'gud',
#  'mrng',
#  'i',
#  'plane',
#  'to',
#  'give',
#  'on',
#  'this',
#  'month',
#  'end',
#  'nothing',
#  'just',
#  'getting',
#  'msgs',
#  'by',
#  'dis',
#  'name',
#  'wit',
#  'different',
#  'no',
#  's',
#  'ü',
#  'eatin',
#  'later',
#  'but',
#  'i',
#  'm',
#  'eatin',
#  'wif',
#  'my',
#  'frens',
#  'now',
#  'lei',
#  'ü',
#  'going',
#  'home',
#  'first',
#  'hi',
#  'this',
#  'is',
#  'roger',
#  'from',
#  'cl',
#  'how',
#  'are',
#  'you',
#  'arngd',
#  'marriage',
#  'is',
#  'while',
#  'u',
#  'r',
#  'walkin',
#  'unfortuntly',
#  'a',
#  'snake',
#  'bites',
#  'u',
#  'bt',
#  'love',
#  'marriage',
#  'is',
#  'dancing',
#  'in',
#  'frnt',
#  'of',
#  'd',
#  'snake',
#  'amp',
#  'sayin',
#  'bite',
#  'me',
#  'bite',
#  'me',
#  'sir',
#  'you',
#  'will',
#  'receive',
#  'the',
#  'account',
#  'no',
#  'another',
#  '1hr',
#  'time',
#  'sorry',
#  'for',
#  'the',
#  'delay',
#  'congrats',
#  '1',
#  'year',
#  'special',
#  'cinema',
#  'pass',
#  'for',
#  '2',
#  'is',
#  'yours',
#  'call',
#  '09061209465',
#  'now',
#  'c',
#  'suprman',
#  'v',
#  'matrix3',
#  'starwars3',
#  'etc',
#  'all',
#  '4',
#  'free',
#  'bx420',
#  'ip4',
#  '5we',
#  '150pm',
#  'dont',
#  'miss',
#  'out',
#  'convey',
#  'my',
#  'regards',
#  'to',
#  'him',
#  'usually',
#  'the',
#  'person',
#  'is',
#  'unconscious',
#  'that',
#  's',
#  'in',
#  'children',
#  'but',
#  'in',
#  'adults',
#  'they',
#  'may',
#  'just',
#  'behave',
#  'abnormally',
#  'i',
#  'll',
#  'call',
#  'you',
#  'now',
#  'what',
#  's',
#  'up',
#  'my',
#  'own',
#  'oga',
#  'left',
#  'my',
#  'phone',
#  'at',
#  'home',
#  'and',
#  'just',
#  'saw',
#  'ur',
#  'messages',
#  'hope',
#  'you',
#  'are',
#  'good',
#  'have',
#  'a',
#  'great',
#  'weekend',
#  'u',
#  'come',
#  'n',
#  'search',
#  'tat',
#  'vid',
#  'not',
#  'finishd',
#  'send',
#  'me',
#  'yetty',
#  's',
#  'number',
#  'pls',
#  'hasn',
#  't',
#  'that',
#  'been',
#  'the',
#  'pattern',
#  'recently',
#  'crap',
#  'weekends',
#  'noice',
#  'text',
#  'me',
#  'when',
#  'you',
#  're',
#  'here',
#  'thts',
#  'wat',
#  'wright',
#  'brother',
#  'did',
#  'to',
#  'fly',
#  'cool',
#  'breeze',
#  'bright',
#  'sun',
#  'fresh',
#  'flower',
#  'twittering',
#  'birds',
#  'all',
#  'these',
#  'waiting',
#  'to',
#  'wish',
#  'u',
#  'goodmorning',
#  'amp',
#  'have',
#  'a',
#  'nice',
#  'day',
#  'sorry',
#  'i',
#  'll',
#  'call',
#  'later',
#  'helloooo',
#  'wake',
#  'up',
#  'sweet',
#  'morning',
#  'welcomes',
#  'you',
#  'enjoy',
#  'this',
#  'day',
#  'with',
#  'full',
#  'of',
#  'joy',
#  'gud',
#  'mrng',
#  'you',
#  'have',
#  'come',
#  'into',
#  'my',
#  'life',
#  'and',
#  'brought',
#  'the',
#  'sun',
#  'shiny',
#  'down',
#  'on',
#  'me',
#  'warming',
#  'my',
#  'heart',
#  'putting',
#  'a',
#  'constant',
#  'smile',
#  'on',
#  'my',
#  'face',
#  'making',
#  'me',
#  'feel',
#  'loved',
#  'and',
#  'cared',
#  'for',
#  'was',
#  'gr8',
#  'to',
#  'see',
#  'that',
#  'message',
#  'so',
#  'when',
#  'r',
#  'u',
#  'leaving',
#  'congrats',
#  'dear',
#  'what',
#  'school',
#  'and',
#  'wat',
#  'r',
#  'ur',
#  'plans',
#  'mm',
#  'i',
#  'had',
#  'my',
#  'food',
#  'da',
#  'from',
#  'out',
#  'please',
#  'dont',
#  'say',
#  'like',
#  'that',
#  'hi',
#  'hi',
#  'hi',
#  'bought',
#  'one',
#  'ringtone',
#  'and',
#  'now',
#  'getting',
#  'texts',
#  'costing',
#  '3',
#  'pound',
#  'offering',
#  'more',
#  'tones',
#  'etc',
#  'haha',
#  'awesome',
#  'i',
#  've',
#  'been',
#  'to',
#  '4u',
#  'a',
#  'couple',
#  'times',
#  'who',
#  'all',
#  's',
#  'coming',
#  'ok',
#  'let',
#  'u',
#  'noe',
#  'when',
#  'i',
#  'leave',
#  'my',
#  'house',
#  'what',
#  'today',
#  'sunday',
#  'sunday',
#  'is',
#  'holiday',
#  'so',
#  'no',
#  'work',
#  'hey',
#  'looks',
#  'like',
#  'i',
#  'was',
#  'wrong',
#  'and',
#  'one',
#  'of',
#  'the',
#  'kappa',
#  'guys',
#  'numbers',
#  'is',
#  'still',
#  'on',
#  'my',
#  'phone',
#  'if',
#  'you',
#  'want',
#  'i',
#  'can',
#  'text',
#  'him',
#  'and',
#  'see',
#  'if',
#  'he',
#  's',
#  'around',
#  'wah',
#  'okie',
#  'okie',
#  'muz',
#  'make',
#  'use',
#  'of',
#  'e',
#  'unlimited',
#  'haha',
#  'hey',
#  'babe',
#  'sorry',
#  'i',
#  'didn',
#  't',
#  'get',
#  'sooner',
#  'gary',
#  'can',
#  'come',
#  'and',
#  'fix',
#  'it',
#  'cause',
#  'he',
#  'thinks',
#  'he',
#  'knows',
#  'what',
#  'it',
#  'is',
#  'but',
#  'he',
#  'doesn',
#  't',
#  'go',
#  'as',
#  'far',
#  'a',
#  'ptbo',
#  'and',
#  'he',
#  'says',
#  'it',
#  'will',
#  'cost',
#  'lt',
#  'gt',
#  'bucks',
#  'i',
#  'don',
#  't',
#  'know',
#  'if',
#  'it',
#  'might',
#  'be',
#  'cheaper',
#  'to',
#  'find',
#  'someone',
#  'there',
#  'we',
#  'don',
#  't',
#  'have',
#  'any',
#  'second',
#  'hand',
#  'machines',
#  'at',
#  'all',
#  'right',
#  'now',
#  'let',
#  'me',
#  'know',
#  'what',
#  'you',
#  'want',
#  'to',
#  'do',
#  'babe',
#  'pick',
#  'ur',
#  'fone',
#  'up',
#  'now',
#  'u',
#  'dumb',
#  'here',
#  'is',
#  'your',
#  'discount',
#  'code',
#  'rp176781',
#  'to',
#  'stop',
#  'further',
#  'messages',
#  'reply',
#  'stop',
#  'www',
#  'regalportfolio',
#  'co',
#  'uk',
#  'customer',
#  'services',
#  '08717205546',
#  'dear',
#  'voucher',
#  'holder',
#  '2',
#  'claim',
#  'this',
#  'weeks',
#  'offer',
#  'at',
#  'your',
#  'pc',
#  'go',
#  'to',
#  'http',
#  'www',
#  'e',
#  'tlp',
#  'co',
#  'uk',
#  'expressoffer',
#  'ts',
#  'cs',
#  'apply',
#  '2',
#  'stop',
#  'texts',
#  'txt',
#  'stop',
#  'to',
#  '80062',
#  'god',
#  'picked',
#  'up',
#  'a',
#  'flower',
#  'and',
#  'dippeditinadew',
#  'lovingly',
#  'touched',
#  'itwhichturnedinto',
#  'u',
#  'and',
#  'the',
#  'he',
#  'gifted',
#  'tomeandsaid',
#  'this',
#  'friend',
#  'is',
#  '4u',
#  'dear',
#  'matthew',
#  'please',
#  'call',
#  '09063440451',
#  'from',
#  'a',
#  'landline',
#  'your',
#  'complimentary',
#  '4',
#  'lux',
#  'tenerife',
#  'holiday',
#  'or',
#  '£1000',
#  'cash',
#  'await',
#  'collection',
#  'ppm150',
#  'sae',
#  't',
#  'cs',
#  'box334',
#  'sk38xh',
#  'sleeping',
#  'nt',
#  'feeling',
#  'well',
#  'some',
#  'of',
#  'them',
#  'told',
#  'accenture',
#  'is',
#  'not',
#  'confirm',
#  'is',
#  'it',
#  'true',
#  'i',
#  'm',
#  'done',
#  'i',
#  'm',
#  'sorry',
#  'i',
#  'hope',
#  'your',
#  'next',
#  'space',
#  'gives',
#  'you',
#  'everything',
#  'you',
#  'want',
#  'remember',
#  'all',
#  'the',
#  'furniture',
#  'is',
#  'yours',
#  'if',
#  'i',
#  'm',
#  'not',
#  'around',
#  'when',
#  'you',
#  'move',
#  'it',
#  'just',
#  'lock',
#  'all',
#  'the',
#  'locks',
#  'and',
#  'leave',
#  'the',
#  'key',
#  'with',
#  'jenne',
#  'oh',
#  'ok',
#  'wait',
#  '4',
#  'me',
#  'there',
#  'my',
#  'lect',
#  'havent',
#  'finish',
#  'don',
#  't',
#  'fret',
#  'i',
#  'll',
#  'buy',
#  'the',
#  'ovulation',
#  'test',
#  'strips',
#  'and',
#  'send',
#  'them',
#  'to',
#  'you',
#  'you',
#  'wont',
#  'get',
#  'them',
#  'til',
#  'like',
#  'march',
#  'can',
#  'you',
#  'send',
#  'me',
#  'your',
#  'postal',
#  'address',
#  'u',
#  'll',
#  'be',
#  'alright',
#  'okay',
#  'idea',
#  'will',
#  'soon',
#  'get',
#  'converted',
#  'to',
#  'live',
#  'aight',
#  'well',
#  'keep',
#  'me',
#  'informed',
#  'lol',
#  'no',
#  'u',
#  'can',
#  'trust',
#  'me',
#  'is',
#  'ur',
#  'lecture',
#  'over',
#  'sorry',
#  'i',
#  'll',
#  'call',
#  'later',
#  'in',
#  'meeting',
#  'any',
#  'thing',
#  'related',
#  'to',
#  'trade',
#  'please',
#  'call',
#  'arul',
#  'lt',
#  'gt',
#  'is',
#  'toshiba',
#  'portege',
#  'm100',
#  'gd',
#  'glad',
#  'to',
#  'see',
#  'your',
#  'reply',
#  'sms',
#  'services',
#  'for',
#  'your',
#  'inclusive',
#  'text',
#  'credits',
#  'pls',
#  'goto',
#  'www',
#  'comuk',
#  'net',
#  'login',
#  '3qxj9',
#  'unsubscribe',
#  'with',
#  'stop',
#  'no',
#  'extra',
#  'charge',
#  'help',
#  '08702840625',
#  'comuk',
#  '220',
#  'cm2',
#  '9ae',
#  'im',
#  'done',
#  'just',
#  'studyn',
#  'in',
#  'library',
#  'thanx',
#  '4',
#  'puttin',
#  'da',
#  'fone',
#  'down',
#  'on',
#  'me',
#  'dont',
#  'let',
#  'studying',
#  'stress',
#  'you',
#  'out',
#  'l8r',
#  ...]

# %%
# Amb el set, agafem les úniques

# %%
# Per cada paraula unica, inicialitzem un dict a 0
dictionary = {word: {'ham': 0, 'spam': 0} for word in list(set(X_train['sms'].sum()))}
len(dictionary)
# Out:
# 7884

# %%
dictionary
# Out:
# {'fireplace': {'ham': 0, 'spam': 0},
#  'places': {'ham': 0, 'spam': 0},
#  'giving': {'ham': 0, 'spam': 0},
#  'comfey': {'ham': 0, 'spam': 0},
#  'copies': {'ham': 0, 'spam': 0},
#  'cheap': {'ham': 0, 'spam': 0},
#  '087187262701': {'ham': 0, 'spam': 0},
#  '81151': {'ham': 0, 'spam': 0},
#  'cn': {'ham': 0, 'spam': 0},
#  'settling': {'ham': 0, 'spam': 0},
#  'rows': {'ham': 0, 'spam': 0},
#  'breaker': {'ham': 0, 'spam': 0},
#  'gbp1': {'ham': 0, 'spam': 0},
#  'flatter': {'ham': 0, 'spam': 0},
#  '5p': {'ham': 0, 'spam': 0},
#  'lucky': {'ham': 0, 'spam': 0},
#  'luvd': {'ham': 0, 'spam': 0},
#  'portions': {'ham': 0, 'spam': 0},
#  'tickets': {'ham': 0, 'spam': 0},
#  'crashed': {'ham': 0, 'spam': 0},
#  'refused': {'ham': 0, 'spam': 0},
#  'milta': {'ham': 0, 'spam': 0},
#  'wind': {'ham': 0, 'spam': 0},
#  'yoyyooo': {'ham': 0, 'spam': 0},
#  'university': {'ham': 0, 'spam': 0},
#  'spoons': {'ham': 0, 'spam': 0},
#  'conditions': {'ham': 0, 'spam': 0},
#  '077xxx': {'ham': 0, 'spam': 0},
#  'tirunelvali': {'ham': 0, 'spam': 0},
#  'picture': {'ham': 0, 'spam': 0},
#  'weeks': {'ham': 0, 'spam': 0},
#  'ktv': {'ham': 0, 'spam': 0},
#  'radio': {'ham': 0, 'spam': 0},
#  'lowes': {'ham': 0, 'spam': 0},
#  'raj': {'ham': 0, 'spam': 0},
#  'expiry': {'ham': 0, 'spam': 0},
#  'mahaveer': {'ham': 0, 'spam': 0},
#  'meaningless': {'ham': 0, 'spam': 0},
#  'valuable': {'ham': 0, 'spam': 0},
#  '08715203656': {'ham': 0, 'spam': 0},
#  'gold': {'ham': 0, 'spam': 0},
#  'finishd': {'ham': 0, 'spam': 0},
#  'moves': {'ham': 0, 'spam': 0},
#  '7876150ppm': {'ham': 0, 'spam': 0},
#  'pub': {'ham': 0, 'spam': 0},
#  'foreign': {'ham': 0, 'spam': 0},
#  '1stone': {'ham': 0, 'spam': 0},
#  'approved': {'ham': 0, 'spam': 0},
#  'andre': {'ham': 0, 'spam': 0},
#  'rolled': {'ham': 0, 'spam': 0},
#  'fall': {'ham': 0, 'spam': 0},
#  'stamps': {'ham': 0, 'spam': 0},
#  'vid': {'ham': 0, 'spam': 0},
#  'panther': {'ham': 0, 'spam': 0},
#  'competition': {'ham': 0, 'spam': 0},
#  'wnevr': {'ham': 0, 'spam': 0},
#  'neglect': {'ham': 0, 'spam': 0},
#  '09058099801': {'ham': 0, 'spam': 0},
#  'sathya': {'ham': 0, 'spam': 0},
#  'offering': {'ham': 0, 'spam': 0},
#  '09065069120': {'ham': 0, 'spam': 0},
#  'treated': {'ham': 0, 'spam': 0},
#  'resuming': {'ham': 0, 'spam': 0},
#  'age23': {'ham': 0, 'spam': 0},
#  'matric': {'ham': 0, 'spam': 0},
#  'recycling': {'ham': 0, 'spam': 0},
#  'crazyin': {'ham': 0, 'spam': 0},
#  '1thing': {'ham': 0, 'spam': 0},
#  'animal': {'ham': 0, 'spam': 0},
#  'requires': {'ham': 0, 'spam': 0},
#  'track': {'ham': 0, 'spam': 0},
#  'supplies': {'ham': 0, 'spam': 0},
#  'lancaster': {'ham': 0, 'spam': 0},
#  '87066': {'ham': 0, 'spam': 0},
#  'widelive': {'ham': 0, 'spam': 0},
#  'pract': {'ham': 0, 'spam': 0},
#  'inside': {'ham': 0, 'spam': 0},
#  '9': {'ham': 0, 'spam': 0},
#  'dt': {'ham': 0, 'spam': 0},
#  'jolt': {'ham': 0, 'spam': 0},
#  'winnersclub': {'ham': 0, 'spam': 0},
#  'birds': {'ham': 0, 'spam': 0},
#  'heads': {'ham': 0, 'spam': 0},
#  'eviction': {'ham': 0, 'spam': 0},
#  'bffs': {'ham': 0, 'spam': 0},
#  'weekends': {'ham': 0, 'spam': 0},
#  'grandma': {'ham': 0, 'spam': 0},
#  'motor': {'ham': 0, 'spam': 0},
#  'brolly': {'ham': 0, 'spam': 0},
#  'clearly': {'ham': 0, 'spam': 0},
#  'vibrate': {'ham': 0, 'spam': 0},
#  'nagar': {'ham': 0, 'spam': 0},
#  'browser': {'ham': 0, 'spam': 0},
#  'stunning': {'ham': 0, 'spam': 0},
#  '3wks': {'ham': 0, 'spam': 0},
#  'impressively': {'ham': 0, 'spam': 0},
#  'arngd': {'ham': 0, 'spam': 0},
#  'ends': {'ham': 0, 'spam': 0},
#  'mall': {'ham': 0, 'spam': 0},
#  'footie': {'ham': 0, 'spam': 0},
#  'receipts—well': {'ham': 0, 'spam': 0},
#  'madoke': {'ham': 0, 'spam': 0},
#  'scouse': {'ham': 0, 'spam': 0},
#  'lover': {'ham': 0, 'spam': 0},
#  'wined': {'ham': 0, 'spam': 0},
#  'meanwhile': {'ham': 0, 'spam': 0},
#  '£50award': {'ham': 0, 'spam': 0},
#  'reltnship': {'ham': 0, 'spam': 0},
#  '08700435505150p': {'ham': 0, 'spam': 0},
#  'kids': {'ham': 0, 'spam': 0},
#  'efreefone': {'ham': 0, 'spam': 0},
#  'somebody': {'ham': 0, 'spam': 0},
#  'm39m51': {'ham': 0, 'spam': 0},
#  'rounds': {'ham': 0, 'spam': 0},
#  'formally': {'ham': 0, 'spam': 0},
#  'pobox114': {'ham': 0, 'spam': 0},
#  'rule': {'ham': 0, 'spam': 0},
#  'coupla': {'ham': 0, 'spam': 0},
#  'shouted': {'ham': 0, 'spam': 0},
#  'blackberry': {'ham': 0, 'spam': 0},
#  'treatin': {'ham': 0, 'spam': 0},
#  '08706091795': {'ham': 0, 'spam': 0},
#  'cancel': {'ham': 0, 'spam': 0},
#  'tog': {'ham': 0, 'spam': 0},
#  'hands': {'ham': 0, 'spam': 0},
#  'prediction': {'ham': 0, 'spam': 0},
#  '88066': {'ham': 0, 'spam': 0},
#  'shhhhh': {'ham': 0, 'spam': 0},
#  'wt': {'ham': 0, 'spam': 0},
#  'mutai': {'ham': 0, 'spam': 0},
#  'betta': {'ham': 0, 'spam': 0},
#  '£6': {'ham': 0, 'spam': 0},
#  'i‘ve': {'ham': 0, 'spam': 0},
#  'mj': {'ham': 0, 'spam': 0},
#  'hv9d': {'ham': 0, 'spam': 0},
#  '48922': {'ham': 0, 'spam': 0},
#  'sky': {'ham': 0, 'spam': 0},
#  'springs': {'ham': 0, 'spam': 0},
#  'fassyole': {'ham': 0, 'spam': 0},
#  'taxes': {'ham': 0, 'spam': 0},
#  'fourth': {'ham': 0, 'spam': 0},
#  'planet': {'ham': 0, 'spam': 0},
#  'january': {'ham': 0, 'spam': 0},
#  'bowa': {'ham': 0, 'spam': 0},
#  'sends': {'ham': 0, 'spam': 0},
#  'murdered': {'ham': 0, 'spam': 0},
#  'doesnt': {'ham': 0, 'spam': 0},
#  'beer': {'ham': 0, 'spam': 0},
#  '500': {'ham': 0, 'spam': 0},
#  'knowing': {'ham': 0, 'spam': 0},
#  'haunt': {'ham': 0, 'spam': 0},
#  'otherwise': {'ham': 0, 'spam': 0},
#  'libertines': {'ham': 0, 'spam': 0},
#  'responce': {'ham': 0, 'spam': 0},
#  'crowd': {'ham': 0, 'spam': 0},
#  'fat': {'ham': 0, 'spam': 0},
#  '40': {'ham': 0, 'spam': 0},
#  'could': {'ham': 0, 'spam': 0},
#  'pobox12n146tf150p': {'ham': 0, 'spam': 0},
#  'smart': {'ham': 0, 'spam': 0},
#  'prob': {'ham': 0, 'spam': 0},
#  'advisors': {'ham': 0, 'spam': 0},
#  'tulip': {'ham': 0, 'spam': 0},
#  'nuther': {'ham': 0, 'spam': 0},
#  'arun': {'ham': 0, 'spam': 0},
#  'sd': {'ham': 0, 'spam': 0},
#  'cali': {'ham': 0, 'spam': 0},
#  'amla': {'ham': 0, 'spam': 0},
#  'shaking': {'ham': 0, 'spam': 0},
#  'fond': {'ham': 0, 'spam': 0},
#  'belong': {'ham': 0, 'spam': 0},
#  'date': {'ham': 0, 'spam': 0},
#  'confused': {'ham': 0, 'spam': 0},
#  'attributed': {'ham': 0, 'spam': 0},
#  'promotion': {'ham': 0, 'spam': 0},
#  'wearing': {'ham': 0, 'spam': 0},
#  'yhl': {'ham': 0, 'spam': 0},
#  'ak': {'ham': 0, 'spam': 0},
#  'dontplease': {'ham': 0, 'spam': 0},
#  'upgrading': {'ham': 0, 'spam': 0},
#  'cuddling': {'ham': 0, 'spam': 0},
#  'grumble': {'ham': 0, 'spam': 0},
#  'inr': {'ham': 0, 'spam': 0},
#  '5th': {'ham': 0, 'spam': 0},
#  'believe': {'ham': 0, 'spam': 0},
#  'il': {'ham': 0, 'spam': 0},
#  'situation': {'ham': 0, 'spam': 0},
#  'mo': {'ham': 0, 'spam': 0},
#  'catches': {'ham': 0, 'spam': 0},
#  '80062': {'ham': 0, 'spam': 0},
#  'simonwatson5120': {'ham': 0, 'spam': 0},
#  'constant': {'ham': 0, 'spam': 0},
#  'nuerologist': {'ham': 0, 'spam': 0},
#  '08712402578': {'ham': 0, 'spam': 0},
#  'advising': {'ham': 0, 'spam': 0},
#  'gsex': {'ham': 0, 'spam': 0},
#  'favour': {'ham': 0, 'spam': 0},
#  'fav': {'ham': 0, 'spam': 0},
#  'contacts': {'ham': 0, 'spam': 0},
#  'themes': {'ham': 0, 'spam': 0},
#  '84122': {'ham': 0, 'spam': 0},
#  'w1j6hl': {'ham': 0, 'spam': 0},
#  'deciding': {'ham': 0, 'spam': 0},
#  'doesn‘t': {'ham': 0, 'spam': 0},
#  'slob': {'ham': 0, 'spam': 0},
#  '9ja': {'ham': 0, 'spam': 0},
#  'jenne': {'ham': 0, 'spam': 0},
#  'buses': {'ham': 0, 'spam': 0},
#  'phony': {'ham': 0, 'spam': 0},
#  'able': {'ham': 0, 'spam': 0},
#  'surya': {'ham': 0, 'spam': 0},
#  'silently': {'ham': 0, 'spam': 0},
#  'thinking': {'ham': 0, 'spam': 0},
#  'dict': {'ham': 0, 'spam': 0},
#  'pocketbabe': {'ham': 0, 'spam': 0},
#  'bloomberg': {'ham': 0, 'spam': 0},
#  'closer': {'ham': 0, 'spam': 0},
#  'notixiquating': {'ham': 0, 'spam': 0},
#  'honest': {'ham': 0, 'spam': 0},
#  'west': {'ham': 0, 'spam': 0},
#  '0906346330': {'ham': 0, 'spam': 0},
#  'snowman': {'ham': 0, 'spam': 0},
#  'large': {'ham': 0, 'spam': 0},
#  '4w': {'ham': 0, 'spam': 0},
#  'meg': {'ham': 0, 'spam': 0},
#  'everyday': {'ham': 0, 'spam': 0},
#  'company': {'ham': 0, 'spam': 0},
#  'mum': {'ham': 0, 'spam': 0},
#  'dwn': {'ham': 0, 'spam': 0},
#  'volcanoes': {'ham': 0, 'spam': 0},
#  'afternoons': {'ham': 0, 'spam': 0},
#  'once': {'ham': 0, 'spam': 0},
#  'depends': {'ham': 0, 'spam': 0},
#  'questioned': {'ham': 0, 'spam': 0},
#  'surrounded': {'ham': 0, 'spam': 0},
#  'dawns': {'ham': 0, 'spam': 0},
#  'la': {'ham': 0, 'spam': 0},
#  'info': {'ham': 0, 'spam': 0},
#  'deleted': {'ham': 0, 'spam': 0},
#  'storming': {'ham': 0, 'spam': 0},
#  'exchanged': {'ham': 0, 'spam': 0},
#  'renting': {'ham': 0, 'spam': 0},
#  'unfolds': {'ham': 0, 'spam': 0},
#  'maps': {'ham': 0, 'spam': 0},
#  'tho': {'ham': 0, 'spam': 0},
#  'painful': {'ham': 0, 'spam': 0},
#  'motivating': {'ham': 0, 'spam': 0},
#  'ceri': {'ham': 0, 'spam': 0},
#  'tantrum': {'ham': 0, 'spam': 0},
#  'lag': {'ham': 0, 'spam': 0},
#  '07808726822': {'ham': 0, 'spam': 0},
#  't91': {'ham': 0, 'spam': 0},
#  'record': {'ham': 0, 'spam': 0},
#  'wrld': {'ham': 0, 'spam': 0},
#  'boston': {'ham': 0, 'spam': 0},
#  'chloe': {'ham': 0, 'spam': 0},
#  'eyes': {'ham': 0, 'spam': 0},
#  'say': {'ham': 0, 'spam': 0},
#  'frm': {'ham': 0, 'spam': 0},
#  'many': {'ham': 0, 'spam': 0},
#  'hvae': {'ham': 0, 'spam': 0},
#  'ago': {'ham': 0, 'spam': 0},
#  'box385': {'ham': 0, 'spam': 0},
#  'skins': {'ham': 0, 'spam': 0},
#  'second': {'ham': 0, 'spam': 0},
#  'verify': {'ham': 0, 'spam': 0},
#  '£2000': {'ham': 0, 'spam': 0},
#  'po19': {'ham': 0, 'spam': 0},
#  'liquor': {'ham': 0, 'spam': 0},
#  'swoop': {'ham': 0, 'spam': 0},
#  'spoil': {'ham': 0, 'spam': 0},
#  'smsrewards': {'ham': 0, 'spam': 0},
#  'awaiting': {'ham': 0, 'spam': 0},
#  'heal': {'ham': 0, 'spam': 0},
#  'anyhow': {'ham': 0, 'spam': 0},
#  'calls': {'ham': 0, 'spam': 0},
#  'sat': {'ham': 0, 'spam': 0},
#  'born': {'ham': 0, 'spam': 0},
#  'housework': {'ham': 0, 'spam': 0},
#  'minimum': {'ham': 0, 'spam': 0},
#  'contacted': {'ham': 0, 'spam': 0},
#  'expired': {'ham': 0, 'spam': 0},
#  '0125698789': {'ham': 0, 'spam': 0},
#  '09071512433': {'ham': 0, 'spam': 0},
#  'jack': {'ham': 0, 'spam': 0},
#  'befor': {'ham': 0, 'spam': 0},
#  '08000938767': {'ham': 0, 'spam': 0},
#  'hogidhe': {'ham': 0, 'spam': 0},
#  'suzy': {'ham': 0, 'spam': 0},
#  'lei': {'ham': 0, 'spam': 0},
#  'jamz': {'ham': 0, 'spam': 0},
#  'mahfuuz': {'ham': 0, 'spam': 0},
#  'mtmsg': {'ham': 0, 'spam': 0},
#  'mite': {'ham': 0, 'spam': 0},
#  'ads': {'ham': 0, 'spam': 0},
#  'eh': {'ham': 0, 'spam': 0},
#  'beauties': {'ham': 0, 'spam': 0},
#  'callfreefone': {'ham': 0, 'spam': 0},
#  'chasing': {'ham': 0, 'spam': 0},
#  'pass': {'ham': 0, 'spam': 0},
#  '08712404000': {'ham': 0, 'spam': 0},
#  'nature': {'ham': 0, 'spam': 0},
#  'resubmit': {'ham': 0, 'spam': 0},
#  'jaya': {'ham': 0, 'spam': 0},
#  'win150ppmx3age16': {'ham': 0, 'spam': 0},
#  'dealing': {'ham': 0, 'spam': 0},
#  'musta': {'ham': 0, 'spam': 0},
#  'teju': {'ham': 0, 'spam': 0},
#  'nvm': {'ham': 0, 'spam': 0},
#  'blessing': {'ham': 0, 'spam': 0},
#  'unintentionally': {'ham': 0, 'spam': 0},
#  'single': {'ham': 0, 'spam': 0},
#  'brainy': {'ham': 0, 'spam': 0},
#  'gua': {'ham': 0, 'spam': 0},
#  'organizer': {'ham': 0, 'spam': 0},
#  'gopalettan': {'ham': 0, 'spam': 0},
#  '24th': {'ham': 0, 'spam': 0},
#  'ias': {'ham': 0, 'spam': 0},
#  'ability': {'ham': 0, 'spam': 0},
#  'ignoring': {'ham': 0, 'spam': 0},
#  'chg': {'ham': 0, 'spam': 0},
#  'oscar': {'ham': 0, 'spam': 0},
#  'retired': {'ham': 0, 'spam': 0},
#  'lucozade': {'ham': 0, 'spam': 0},
#  'hun': {'ham': 0, 'spam': 0},
#  '9t': {'ham': 0, 'spam': 0},
#  'snatch': {'ham': 0, 'spam': 0},
#  'words': {'ham': 0, 'spam': 0},
#  'mat': {'ham': 0, 'spam': 0},
#  'inde': {'ham': 0, 'spam': 0},
#  'schools': {'ham': 0, 'spam': 0},
#  'forum': {'ham': 0, 'spam': 0},
#  'pretsovru': {'ham': 0, 'spam': 0},
#  'big': {'ham': 0, 'spam': 0},
#  'sabarish': {'ham': 0, 'spam': 0},
#  'cttergg': {'ham': 0, 'spam': 0},
#  'selflessness': {'ham': 0, 'spam': 0},
#  'braved': {'ham': 0, 'spam': 0},
#  'woo': {'ham': 0, 'spam': 0},
#  'fantasies': {'ham': 0, 'spam': 0},
#  'infections': {'ham': 0, 'spam': 0},
#  'box245c2150pm': {'ham': 0, 'spam': 0},
#  'locaxx': {'ham': 0, 'spam': 0},
#  'letters': {'ham': 0, 'spam': 0},
#  'knee': {'ham': 0, 'spam': 0},
#  'yeah': {'ham': 0, 'spam': 0},
#  'accomodate': {'ham': 0, 'spam': 0},
#  'juliana': {'ham': 0, 'spam': 0},
#  'system': {'ham': 0, 'spam': 0},
#  'forget': {'ham': 0, 'spam': 0},
#  'shouting': {'ham': 0, 'spam': 0},
#  'cr': {'ham': 0, 'spam': 0},
#  'drops': {'ham': 0, 'spam': 0},
#  '6months': {'ham': 0, 'spam': 0},
#  'because': {'ham': 0, 'spam': 0},
#  'covers': {'ham': 0, 'spam': 0},
#  '25': {'ham': 0, 'spam': 0},
#  'inpersonation': {'ham': 0, 'spam': 0},
#  ...}

# %% [markdown]
# ### get word frequencies for ham/spam

# %%
def count_words(message):
    for word in message.sms: dictionary[word][message.Label] +=1 

_ = X_train.apply(count_words, axis = 1)

# Ho guardem en memoria però no cal. Ho podem borrar
# del(_)

# %%
# check
dictionary['love']
# Out:
# {'ham': 153, 'spam': 9}

# %% [markdown]
# ### prior

# %%
prior = X_train.Label.value_counts(normalize = True)
prior
# Out:
# ham     0.869195
# spam    0.130805
# Name: Label, dtype: float64

# %%
prior['ham']
# Out:
# 0.8691945254655598

# %% [markdown]
# Passem el diccionaria proporcio. dividim el 153 de love de NO_SPAM, per totes les paraules que estan a NO_SPAM. Suma de totes les paraules.

# %% [markdown]
# ### likelihood functions
# - we need to know the total number of counts for each type of message

# %%
# total number of words in HAM messages
n_ham = sum([counts['ham'] for word, counts in dictionary.items()])
n_ham
# Out:
# 57342

# %% [markdown]
# #### Com que estem a test, si després ens ve una paraula que no tenim (nova). Multiplicarem per 1 les dues (ens quedarem igual).

# %%
def ham_word_likelihood(word):
    if word in dictionary:
        return dictionary[word]['ham'] /n_ham
    else:
        return 1

# %%
# total number of words in SPAM messages
n_spam = sum([counts['spam'] for word, counts in dictionary.items()])
n_spam
# Out:
# 14814

# %%
def spam_word_likelihood(word):
    if word in dictionary:
        return dictionary[word]['spam'] /n_spam
    else:
        return 1

# %% [markdown]
# ### Classify

# %%
prior
# Out:
# ham     0.869195
# spam    0.130805
# Name: Label, dtype: float64

# %%
def classify(message):
    post_ham, post_spam = prior # és una tupla
    for word in message:
        post_ham *= ham_word_likelihood(word)
        post_spam *= spam_word_likelihood(word)
    return 'spam' if post_spam > post_ham else ('ham' if post_ham > post_spam else '??')

# %%
classify(['loving']), classify(['£2000'])
# Out:
# ('ham', 'spam')

# %%
classify(['secret', 'source', 'of', 'infinite', 'power'])
# Out:
# 'ham'

# %% [markdown]
# ### test

# %%
X_test['predicted'] = X_test.sms.apply(classify)

# %%
X_test.head()
# Out:
#      Label                                                SMS  \
# 4062   ham  Aight I've been set free, think you could text...
# 494    ham                 What class of  &lt;#&gt;  reunion?
# 1396   ham  Thats cool! I am a gentleman and will treat yo...
# 2575  spam  Your next amazing xxx PICSFREE1 video will be ...
# 3120   ham                           Stop knowing me so well!
#
#                                                     sms predicted
# 4062  [aight, i, ve, been, set, free, think, you, co...       ham
# 494                  [what, class, of, lt, gt, reunion]       ham
# 1396  [thats, cool, i, am, a, gentleman, and, will, ...       ham
# 2575  [your, next, amazing, xxx, picsfree1, video, w...       ham
# 3120                      [stop, knowing, me, so, well]       ham

# %%
pd.concat((X_test.groupby('Label').predicted.value_counts().to_frame('n'), X_test.groupby('Label').predicted.value_counts(normalize = True).to_frame('%')), axis = 1)
# Out:
#                    n         %
# Label predicted
# ham   ham        903  0.949527
#       ??          40  0.042061
#       spam         8  0.008412
# spam  spam       117  0.713415
#       ??          41  0.250000
#       ham          6  0.036585

# %% [markdown]
# ##### not bad but many unclassified messages ... why ???

# %% [markdown]
# - És perque hi han paraules que són 100% ham i llavors quan evaulem per spam és 0.

# %% [markdown]
# ### Per evitar / suavitzar les funcions de likelyhood a partir de mostres que no són suficientment representatives.

# %% [markdown]
# Es pot fer laplacian smoothing &rarr; És posar un 1 on hi ha el 0 i sumar +1 a totes les altres.

# %% [markdown]
# És el que hi ha al següent `Notebook nb47.2`

# %% [markdown]
# ### Ho podem fer inicialitzat el diccionari a 1.

# %%
def classify_3(message):
    post_ham, post_spam = prior # és una tupla
    for word in message:
        post_ham *= ham_word_likelihood(word)
        post_spam *= spam_word_likelihood(word)    
    if post_spam > post_ham:
        return 'spam'
    else:
        if post_ham > post_spam:
            'ham'
        else:
            print(message)
            return '??'

# %%
def classify_2(message):
    post_ham, post_spam = prior # és una tupla
    for word in message:
        post_ham *= ham_word_likelihood(word)
        post_spam *= spam_word_likelihood(word)
        print(f'paraula: {word}')
        print(f'ham: {ham_word_likelihood(word)} i total: {post_ham}')
        print(f'spam: {spam_word_likelihood(word)} i total: {post_spam}')
    
    if post_spam > post_ham:
        return 'spam'
    else:
        if post_ham > post_spam:
            'ham'
        else:
            print(message)
            return '??'

classify_2(X_test.loc[2370]['sms'])
# Out:
# paraula: a
# ham: 0.01482334065780754 i total: 0.012884366548877363
# spam: 0.01977858782233023 i total: 0.002587147565721006
# paraula: boy
# ham: 0.00040110215897596875 i total: 5.167947239792462e-06
# spam: 0.0 i total: 0.0
# paraula: loved
# ham: 0.0001395137944264239 i total: 7.209999288190104e-10
# spam: 0.0 i total: 0.0
# paraula: a
# ham: 0.01482334065780754 i total: 1.068762755913918e-11
# spam: 0.01977858782233023 i total: 0.0
# paraula: gal
# ham: 0.00010463534581981794 i total: 1.1183036056439448e-15
# spam: 0.0 i total: 0.0
# paraula: he
# ham: 0.00303442502877472 i total: 3.3934084507350002e-18
# spam: 0.0 i total: 0.0
# paraula: propsd
# ham: 1.743922430330299e-05 i total: 5.917841112509156e-23
# spam: 0.0 i total: 0.0
# paraula: bt
# ham: 0.0002790275888528478 i total: 1.6512409368376844e-26
# spam: 0.0008100445524503848 i total: 0.0
# paraula: she
# ham: 0.0023194168323392977 i total: 3.8299160231490365e-29
# spam: 0.0 i total: 0.0
# paraula: didnt
# ham: 0.0003662237103693628 i total: 1.4026060564007144e-32
# spam: 0.0 i total: 0.0
# paraula: mind
# ham: 0.0005231767290990897 i total: 7.33810848802299e-36
# spam: 6.750371270419872e-05 i total: 0.0
# paraula: he
# ham: 0.00303442502877472 i total: 2.2266940059921177e-38
# spam: 0.0 i total: 0.0
# paraula: gv
# ham: 1.743922430330299e-05 i total: 3.883181622531683e-43
# spam: 0.0 i total: 0.0
# paraula: lv
# ham: 1.743922430330299e-05 i total: 6.771967532579406e-48
# spam: 0.0 i total: 0.0
# paraula: lttrs
# ham: 1.743922430330299e-05 i total: 1.1809786077533756e-52
# spam: 0.0 i total: 0.0
# paraula: bt
# ham: 0.0002790275888528478 i total: 3.2952561340821754e-56
# spam: 0.0008100445524503848 i total: 0.0
# paraula: her
# ham: 0.0016916047574203898 i total: 5.57427095333213e-59
# spam: 0.0007425408397461861 i total: 0.0
# paraula: frnds
# ham: 0.0001395137944264239 i total: 7.776876918603648e-63
# spam: 0.0 i total: 0.0
# paraula: threw
# ham: 1.743922430330299e-05 i total: 1.3562270096270881e-67
# spam: 0.0 i total: 0.0
# paraula: thm
# ham: 3.487844860660598e-05 i total: 4.730309405416931e-72
# spam: 0.0 i total: 0.0
# paraula: again
# ham: 0.0008370827665585435 i total: 3.9596604837643033e-75
# spam: 0.0002025111381125962 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 7.457767992859418e-78
# spam: 0.0004050222762251924 i total: 0.0
# paraula: boy
# ham: 0.00040110215897596875 i total: 2.9913268430777895e-81
# spam: 0.0 i total: 0.0
# paraula: decided
# ham: 0.00020927069163963587 i total: 6.259970373710975e-85
# spam: 0.0 i total: 0.0
# paraula: 2
# ham: 0.004673712113285201 i total: 2.925729936441947e-87
# spam: 0.01012555690562981 i total: 0.0
# paraula: aproach
# ham: 1.743922430330299e-05 i total: 5.102246061249951e-92
# spam: 0.0 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 9.609755059380467e-95
# spam: 0.0004050222762251924 i total: 0.0
# paraula: gal
# ham: 0.00010463534581981794 i total: 1.0055200438820202e-98
# spam: 0.0 i total: 0.0
# paraula: dt
# ham: 1.743922430330299e-05 i total: 1.7535489586725615e-103
# spam: 0.0 i total: 0.0
# paraula: time
# ham: 0.002703079767011963 i total: 4.739982710652698e-106
# spam: 0.001012555690562981 i total: 0.0
# paraula: a
# ham: 0.01482334065780754 i total: 7.026237843212294e-108
# spam: 0.01977858782233023 i total: 0.0
# paraula: truck
# ham: 1.743922430330299e-05 i total: 1.2253213775613502e-112
# spam: 0.0 i total: 0.0
# paraula: was
# ham: 0.0029472289072582053 i total: 3.611302584630257e-115
# spam: 0.0004050222762251924 i total: 0.0
# paraula: speeding
# ham: 1.743922430330299e-05 i total: 6.297831580046487e-120
# spam: 0.0 i total: 0.0
# paraula: towards
# ham: 8.719612151651495e-05 i total: 5.491464877442788e-124
# spam: 0.0 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 1.0342823877154985e-126
# spam: 0.0004050222762251924 i total: 0.0
# paraula: gal
# ham: 0.00010463534581981794 i total: 1.082224953139582e-130
# spam: 0.0 i total: 0.0
# paraula: wn
# ham: 3.487844860660598e-05 i total: 3.774632740886547e-135
# spam: 0.0 i total: 0.0
# paraula: it
# ham: 0.010184506993128945 i total: 3.8442773546052515e-137
# spam: 0.0018226002430133657 i total: 0.0
# paraula: was
# ham: 0.0029472289072582053 i total: 1.1329965347010699e-139
# spam: 0.0004050222762251924 i total: 0.0
# paraula: about
# ham: 0.0024066129538558123 i total: 2.726684137085341e-142
# spam: 0.00047252598892939113 i total: 0.0
# paraula: 2
# ham: 0.004673712113285201 i total: 1.2743736680598363e-144
# spam: 0.01012555690562981 i total: 0.0
# paraula: hit
# ham: 0.0001569530187297269 i total: 2.0001679419166627e-148
# spam: 0.0002700148508167949 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 3.767188757402943e-151
# spam: 0.0004050222762251924 i total: 0.0
# paraula: girl
# ham: 0.0004708590561891807 i total: 1.7738149427972422e-154
# spam: 0.0002700148508167949 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 3.3408673192791004e-157
# spam: 0.0004050222762251924 i total: 0.0
# paraula: boy
# ham: 0.00040110215897596875 i total: 1.3400290946151043e-160
# spam: 0.0 i total: 0.0
# paraula: ran
# ham: 6.975689721321196e-05 i total: 9.347627181577932e-165
# spam: 0.0 i total: 0.0
# paraula: like
# ham: 0.003278574169020962 i total: 3.0646889019159622e-167
# spam: 0.0005400297016335898 i total: 0.0
# paraula: hell
# ham: 8.719612151651495e-05 i total: 2.67228985901779e-171
# spam: 0.0 i total: 0.0
# paraula: n
# ham: 0.00204038924348645 i total: 5.452511483817821e-174
# spam: 0.0005400297016335898 i total: 0.0
# paraula: saved
# ham: 5.231767290990897e-05 i total: 2.852627123479032e-178
# spam: 0.0 i total: 0.0
# paraula: her
# ham: 0.0016916047574203898 i total: 4.825517613223572e-181
# spam: 0.0007425408397461861 i total: 0.0
# paraula: she
# ham: 0.0023194168323392977 i total: 1.1192386776860506e-183
# spam: 0.0 i total: 0.0
# paraula: asked
# ham: 0.0002964668131561508 i total: 3.318171239346877e-187
# spam: 0.0002700148508167949 i total: 0.0
# paraula: hw
# ham: 0.0001569530187297269 i total: 5.207969926776515e-191
# spam: 0.0 i total: 0.0
# paraula: cn
# ham: 3.487844860660598e-05 i total: 1.8164591143582417e-195
# spam: 0.0 i total: 0.0
# paraula: u
# ham: 0.014282724704405149 i total: 2.5943985467186356e-197
# spam: 0.009315512353179425 i total: 0.0
# paraula: run
# ham: 0.0003139060374594538 i total: 8.143973673910126e-201
# spam: 0.0 i total: 0.0
# paraula: so
# ham: 0.005946775487426319 i total: 4.8430383014254e-203
# spam: 0.0014175779667881733 i total: 0.0
# paraula: fast
# ham: 0.00019183146733633288 i total: 9.290471437284957e-207
# spam: 6.750371270419872e-05 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 1.7498010450050144e-209
# spam: 0.0004050222762251924 i total: 0.0
# paraula: boy
# ham: 0.00040110215897596875 i total: 7.018489769299176e-213
# spam: 0.0 i total: 0.0
# paraula: replied
# ham: 6.975689721321196e-05 i total: 4.895880694289823e-217
# spam: 6.750371270419872e-05 i total: 0.0
# paraula: boost
# ham: 5.231767290990897e-05 i total: 2.5614108476979297e-221
# spam: 0.0 i total: 0.0
# paraula: is
# ham: 0.01037633846046528 i total: 2.6578065892021003e-223
# spam: 0.008032941811799648 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 5.005809208500346e-226
# spam: 0.0004050222762251924 i total: 0.0
# paraula: secret
# ham: 5.231767290990897e-05 i total: 2.618922888197314e-230
# spam: 0.0006075334143377885 i total: 0.0
# paraula: of
# ham: 0.007324474207387255 i total: 1.918223314573736e-232
# spam: 0.00479276360199811 i total: 0.0
# paraula: my
# ham: 0.010760001395137945 i total: 2.0640085540999533e-234
# spam: 0.00047252598892939113 i total: 0.0
# paraula: energy
# ham: 6.975689721321196e-05 i total: 1.4397883255554068e-238
# spam: 0.0002025111381125962 i total: 0.0
# paraula: n
# ham: 0.00204038924348645 i total: 2.9377286123606188e-241
# spam: 0.0005400297016335898 i total: 0.0
# paraula: instantly
# ham: 1.743922430330299e-05 i total: 5.123170821318787e-246
# spam: 6.750371270419872e-05 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 9.649165510488455e-249
# spam: 0.0004050222762251924 i total: 0.0
# paraula: girl
# ham: 0.0004708590561891807 i total: 4.543396965281788e-252
# spam: 0.0002700148508167949 i total: 0.0
# paraula: shouted
# ham: 3.487844860660598e-05 i total: 1.584666375529904e-256
# spam: 0.0 i total: 0.0
# paraula: our
# ham: 0.0008545219908618465 i total: 1.35413226606964e-259
# spam: 0.004320237613068718 i total: 0.0
# paraula: energy
# ham: 6.975689721321196e-05 i total: 9.446006529731365e-264
# spam: 0.0002025111381125962 i total: 0.0
# paraula: n
# ham: 0.00204038924348645 i total: 1.9273530117166645e-266
# spam: 0.0005400297016335898 i total: 0.0
# paraula: thy
# ham: 1.743922430330299e-05 i total: 3.3611541482973464e-271
# spam: 0.0 i total: 0.0
# paraula: lived
# ham: 1.743922430330299e-05 i total: 5.8615921110134746e-276
# spam: 0.0 i total: 0.0
# paraula: happily
# ham: 1.743922430330299e-05 i total: 1.0222161959843525e-280
# spam: 0.0 i total: 0.0
# paraula: 2gthr
# ham: 1.743922430330299e-05 i total: 1.7826657528240253e-285
# spam: 0.0 i total: 0.0
# paraula: drinking
# ham: 3.487844860660598e-05 i total: 6.217661584262932e-290
# spam: 0.0 i total: 0.0
# paraula: boost
# ham: 5.231767290990897e-05 i total: 3.252935850299745e-294
# spam: 0.0 i total: 0.0
# paraula: evrydy
# ham: 1.743922430330299e-05 i total: 5.672867793763288e-299
# spam: 0.0 i total: 0.0
# paraula: moral
# ham: 0.0001395137944264239 i total: 7.914433111873724e-303
# spam: 0.0 i total: 0.0
# paraula: of
# ham: 0.007324474207387255 i total: 5.796906119401074e-305
# spam: 0.00479276360199811 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 1.0918102976793903e-307
# spam: 0.0004050222762251924 i total: 0.0
# paraula: story
# ham: 0.0002790275888528478 i total: 3.0464519484617e-311
# spam: 0.0 i total: 0.0
# paraula: i
# ham: 0.0414181577203446 i total: 1.261784272887e-312
# spam: 0.00317267449709734 i total: 0.0
# paraula: hv
# ham: 6.975689721321196e-05 i total: 8.8018155e-317
# spam: 0.0 i total: 0.0
# paraula: free
# ham: 0.0008545219908618465 i total: 7.521e-320
# spam: 0.011745646010530578 i total: 0.0
# paraula: msgs
# ham: 8.719612151651495e-05 i total: 5e-324
# spam: 0.0005400297016335898 i total: 0.0
# paraula: d
# ham: 0.0018834362247567228 i total: 0.0
# spam: 0.0004050222762251924 i total: 0.0
# paraula: gud
# ham: 0.0009591573366816644 i total: 0.0
# spam: 0.0 i total: 0.0
# paraula: ni8
# ham: 0.00019183146733633288 i total: 0.0
# spam: 0.0 i total: 0.0
# ['a', 'boy', 'loved', 'a', 'gal', 'he', 'propsd', 'bt', 'she', 'didnt', 'mind', 'he', 'gv', 'lv', 'lttrs', 'bt', 'her', 'frnds', 'threw', 'thm', 'again', 'd', 'boy', 'decided', '2', 'aproach', 'd', 'gal', 'dt', 'time', 'a', 'truck', 'was', 'speeding', 'towards', 'd', 'gal', 'wn', 'it', 'was', 'about', '2', 'hit', 'd', 'girl', 'd', 'boy', 'ran', 'like', 'hell', 'n', 'saved', 'her', 'she', 'asked', 'hw', 'cn', 'u', 'run', 'so', 'fast', 'd', 'boy', 'replied', 'boost', 'is', 'd', 'secret', 'of', 'my', 'energy', 'n', 'instantly', 'd', 'girl', 'shouted', 'our', 'energy', 'n', 'thy', 'lived', 'happily', '2gthr', 'drinking', 'boost', 'evrydy', 'moral', 'of', 'd', 'story', 'i', 'hv', 'free', 'msgs', 'd', 'gud', 'ni8']
# '??'

# %%
dictionary = {word: {'ham': 1, 'spam': 1} for word in list(set(X_train['sms'].sum()))}
n_ham = sum([counts['ham'] for word, counts in dictionary.items()])
_ = X_train.apply(count_words, axis = 1)
X_test['predicted2'] = X_test.sms.apply(classify_3)

# %%
pd.concat((X_test.groupby('Label')['predicted2'].value_counts().to_frame('n'), X_test.groupby('Label')['predicted2'].value_counts(normalize = True).to_frame('%')), axis = 1)
# Out:
#                    n    %
# Label predicted2
# spam  spam        41  1.0

# %% [markdown]
# ### Abans:

# %%
pd.concat((X_test.groupby('Label').predicted.value_counts().to_frame('n'), X_test.groupby('Label').predicted.value_counts(normalize = True).to_frame('%')), axis = 1)
# Out:
#                    n         %
# Label predicted
# ham   ham        903  0.949527
#       ??          40  0.042061
#       spam         8  0.008412
# spam  spam       117  0.713415
#       ??          41  0.250000
#       ham          6  0.036585
