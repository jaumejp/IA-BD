# %% [markdown]
# ### mplsoccer - Introducció
#
# - *mplsoccer* és un mòdul que ens dóna accés a dades obertes de partits de futbol
#
# - també aporta funcions específiques per analitzar/visualitzar aquestes dades
#
# - hi ha altres mòduls d'aquest estil però són de pagament

# %%
import requests
from pandas import json_normalize
events = requests.get('https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/8658.json')
events = events.json()
df = json_normalize(events, sep = '_')

# %% [markdown]
# Bàsicament ens interessen dues classes:
#
# - Pitch és una classe per dibuixar el camp

# %%
from mplsoccer.pitch import Pitch

# %%
pitch = Pitch(pitch_color = 'grass', line_color = 'white', stripe = True)
fig, axs = pitch.draw(figsize = (5, 3))

# %% [markdown]
# - statsbomb és una submòdul que permet descarregar dades del servidor directament a un pd.DataFrame()

# %%
import mplsoccer.statsbomb as sb
import pandas as pd
pd.set_option('display.max.columns', None)

# %% [markdown]
# #### Funcionalitat bàsica:
#
# - podem veure de quines competicions hi ha partits

# %%
df_competitions = sb.Sbopen().competition()
df_competitions.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0               9         27      Germany     1. Bundesliga
# 1              16          4       Europe  Champions League
# 2              16          1       Europe  Champions League
# 3              16          2       Europe  Champions League
# 4              16         27       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2015/2016  2023-12-12T07:43:33.436182                     None
# 1   2018/2019  2023-03-07T12:20:48.118250  2021-06-13T16:17:31.694
# 2   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None  2023-12-12T07:43:33.436182
# 1                None  2023-03-07T12:20:48.118250
# 2                None  2021-01-23T21:55:30.425330
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
df_competitions.groupby(['competition_name', 'competition_gender']).season_name.value_counts()
# Out:
# competition_name    competition_gender  season_name
# 1. Bundesliga       male                2015/2016      1
# Champions League    male                1970/1971      1
#                                         1971/1972      1
#                                         1972/1973      1
#                                         1999/2000      1
#                                                       ..
# UEFA Euro           male                2020           1
# UEFA Europa League  male                1988/1989      1
# UEFA Women's Euro   female              2022           1
# Women's World Cup   female              2019           1
#                                         2023           1
# Name: season_name, Length: 70, dtype: int64

# %% [markdown]
# - localitzem la competició "La Liga", temporada 2008/2009 (el Barça de les 6 copes)

# %%
df_competitions.loc[(df_competitions.competition_name == 'La Liga') & (df_competitions.season_name == '2008/2009')]
# Out:
#     competition_id  season_id country_name competition_name  \
# 47              11         41        Spain          La Liga
#
#    competition_gender  competition_youth  competition_international  \
# 47               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 47   2008/2009  2023-04-19T10:46:29.203565  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 47                None  2023-04-19T10:46:29.203565

# %% [markdown]
# - amb els valors de *competition_id* i *season_id* podem veure quins partits hi ha

# %%
df_match = sb.Sbopen().match(competition_id = 11, season_id = 41)
df_match[['match_id', 'match_date', 'home_team_name', 'away_team_name', 'home_score', 'away_score']].head()
# Out:
#    match_id match_date home_team_name   away_team_name  home_score  away_score
# 0     69225 2008-12-13      Barcelona      Real Madrid           2           0
# 1     69212 2008-10-04      Barcelona  Atlético Madrid           6           1
# 2     69235 2008-11-01         Málaga        Barcelona           1           4
# 3     69232 2008-10-25      Barcelona          Almería           5           0
# 4     69216 2009-03-07      Barcelona    Athletic Club           2           0

# %% [markdown]
# - el valor *match_id* ens permet descarregar dades d'un partit en concret, per exemple les alineacions

# %%
lineup = sb.Sbopen().lineup(69212)
lineup.groupby('team_name')[['player_id', 'player_nickname']].value_counts()
# Out:
# team_name        player_id  player_nickname
# Atlético Madrid  3237       Sergio Agüero              1
#                  5504       Éver Banega                1
#                  26502      Paulo Assunção             1
#                  26391      Luis García                1
#                  26124      Maxi Rodríguez             1
#                  26120      Luis Perea                 1
#                  26118      Antonio López              1
#                  26083      Florent Sinama-Pongolle    1
#                  26057      Mariano Pernía             1
#                  23991      De las Cuevas              1
#                  20256      Grégory Coupet             1
#                  19731      Tomáš Ujfaluši             1
#                  19728      Johnny Heitinga            1
#                  6391       Raúl García                1
# Barcelona        20176      Víctor Valdés              1
#                  20169      Seydou Kéita               1
#                  20131      Xavi                       1
#                  20125      Carles Puyol               1
#                  19298      Samuel Eto'o               1
#                  15516      Thierry Henry              1
#                  11270      Eiður Guðjohnsen           1
#                  5558       Rafael Márquez             1
#                  5503       Lionel Messi               1
#                  5216       Andrés Iniesta             1
#                  5213       Gerard Piqué               1
#                  5203       Sergio Busquets            1
#                  4913       Bojan                      1
#                  20177      Éric Abidal                1
# dtype: int64

# %% [markdown]
# - o descarregar totes les dades del partit,

# %%
events, related, freeze, tactics = sb.Sbopen().event(69212)
events.head()
# Out:
#                                      id  index  period        timestamp  \
# 0  1e6f7e33-d7e8-40f5-b351-94fa0af84858      1       1         00:00:00
# 1  5dd82bbf-62cd-4a09-8315-b678744d5256      2       1         00:00:00
# 2  bf426dea-daf4-4be1-b87c-efd98956426a      3       1         00:00:00
# 3  d64279fd-a02d-413c-baf2-f2541fa997c4      4       1         00:00:00
# 4  ec5c278f-0e80-4c42-8bc5-24cc3d86e573      5       1  00:00:00.410000
#
#    minute  second  possession  duration  match_id  type_id    type_name  \
# 0       0       0           1  0.000000     69212       35  Starting XI
# 1       0       0           1  0.000000     69212       35  Starting XI
# 2       0       0           1  0.000000     69212       18   Half Start
# 3       0       0           1  0.000000     69212       18   Half Start
# 4       0       0           2  4.963368     69212       30         Pass
#
#    possession_team_id possession_team_name  play_pattern_id play_pattern_name  \
# 0                 217            Barcelona                1      Regular Play
# 1                 217            Barcelona                1      Regular Play
# 2                 217            Barcelona                1      Regular Play
# 3                 217            Barcelona                1      Regular Play
# 4                 217            Barcelona                9     From Kick Off
#
#    team_id        team_name tactics_formation  off_camera  player_id  \
# 0      217        Barcelona               433         NaN        NaN
# 1      212  Atlético Madrid               442         NaN        NaN
# 2      217        Barcelona              None         NaN        NaN
# 3      212  Atlético Madrid              None         NaN        NaN
# 4      217        Barcelona              None         1.0    19298.0
#
#           player_name  position_id   position_name  pass_recipient_id  \
# 0                 NaN          NaN             NaN                NaN
# 1                 NaN          NaN             NaN                NaN
# 2                 NaN          NaN             NaN                NaN
# 3                 NaN          NaN             NaN                NaN
# 4  Samuel Eto''o Fils         23.0  Center Forward             5203.0
#
#         pass_recipient_name  pass_length  pass_angle  pass_height_id  \
# 0                       NaN          NaN         NaN             NaN
# 1                       NaN          NaN         NaN             NaN
# 2                       NaN          NaN         NaN             NaN
# 3                       NaN          NaN         NaN             NaN
# 4  Sergio Busquets i Burgos    14.946571    2.925826             1.0
#
#   pass_height_name  end_x  end_y  sub_type_id sub_type_name  body_part_id  \
# 0              NaN    NaN    NaN          NaN           NaN           NaN
# 1              NaN    NaN    NaN          NaN           NaN           NaN
# 2              NaN    NaN    NaN          NaN           NaN           NaN
# 3              NaN    NaN    NaN          NaN           NaN           NaN
# 4      Ground Pass   45.4   43.2         65.0      Kick Off          40.0
#
#   body_part_name     x     y pass_switch  under_pressure  outcome_id  \
# 0            NaN   NaN   NaN         NaN             NaN         NaN
# 1            NaN   NaN   NaN         NaN             NaN         NaN
# 2            NaN   NaN   NaN         NaN             NaN         NaN
# 3            NaN   NaN   NaN         NaN             NaN         NaN
# 4     Right Foot  60.0  40.0         NaN             NaN         NaN
#
#   outcome_name  counterpress  out  technique_id technique_name dribble_nutmeg  \
# 0          NaN           NaN  NaN           NaN            NaN            NaN
# 1          NaN           NaN  NaN           NaN            NaN            NaN
# 2          NaN           NaN  NaN           NaN            NaN            NaN
# 3          NaN           NaN  NaN           NaN            NaN            NaN
# 4          NaN           NaN  NaN           NaN            NaN            NaN
#
#   ball_recovery_recovery_failure foul_won_defensive pass_assisted_shot_id  \
# 0                            NaN                NaN                   NaN
# 1                            NaN                NaN                   NaN
# 2                            NaN                NaN                   NaN
# 3                            NaN                NaN                   NaN
# 4                            NaN                NaN                   NaN
#
#   pass_goal_assist  shot_statsbomb_xg  end_z shot_key_pass_id  \
# 0              NaN                NaN    NaN              NaN
# 1              NaN                NaN    NaN              NaN
# 2              NaN                NaN    NaN              NaN
# 3              NaN                NaN    NaN              NaN
# 4              NaN                NaN    NaN              NaN
#
#    goalkeeper_position_id goalkeeper_position_name foul_committed_penalty  \
# 0                     NaN                      NaN                    NaN
# 1                     NaN                      NaN                    NaN
# 2                     NaN                      NaN                    NaN
# 3                     NaN                      NaN                    NaN
# 4                     NaN                      NaN                    NaN
#
#   foul_won_penalty pass_shot_assist  bad_behaviour_card_id  \
# 0              NaN              NaN                    NaN
# 1              NaN              NaN                    NaN
# 2              NaN              NaN                    NaN
# 3              NaN              NaN                    NaN
# 4              NaN              NaN                    NaN
#
#   bad_behaviour_card_name aerial_won pass_cross pass_cut_back pass_no_touch  \
# 0                     NaN        NaN        NaN           NaN           NaN
# 1                     NaN        NaN        NaN           NaN           NaN
# 2                     NaN        NaN        NaN           NaN           NaN
# 3                     NaN        NaN        NaN           NaN           NaN
# 4                     NaN        NaN        NaN           NaN           NaN
#
#   foul_committed_offensive  substitution_replacement_id  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#   substitution_replacement_name shot_first_time shot_one_on_one  \
# 0                           NaN             NaN             NaN
# 1                           NaN             NaN             NaN
# 2                           NaN             NaN             NaN
# 3                           NaN             NaN             NaN
# 4                           NaN             NaN             NaN
#
#    foul_committed_card_id foul_committed_card_name block_offensive  \
# 0                     NaN                      NaN             NaN
# 1                     NaN                      NaN             NaN
# 2                     NaN                      NaN             NaN
# 3                     NaN                      NaN             NaN
# 4                     NaN                      NaN             NaN
#
#   foul_committed_advantage foul_won_advantage pass_deflected
# 0                      NaN                NaN            NaN
# 1                      NaN                NaN            NaN
# 2                      NaN                NaN            NaN
# 3                      NaN                NaN            NaN
# 4                      NaN                NaN            NaN

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3640 entries, 0 to 3639
# Data columns (total 75 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3640 non-null   object
#  1   index                           3640 non-null   int64
#  2   period                          3640 non-null   int64
#  3   timestamp                       3640 non-null   object
#  4   minute                          3640 non-null   int64
#  5   second                          3640 non-null   int64
#  6   possession                      3640 non-null   int64
#  7   duration                        2647 non-null   float64
#  8   match_id                        3640 non-null   int64
#  9   type_id                         3640 non-null   int64
#  10  type_name                       3640 non-null   object
#  11  possession_team_id              3640 non-null   int64
#  12  possession_team_name            3640 non-null   object
#  13  play_pattern_id                 3640 non-null   int64
#  14  play_pattern_name               3640 non-null   object
#  15  team_id                         3640 non-null   int64
#  16  team_name                       3640 non-null   object
#  17  tactics_formation               4 non-null      object
#  18  off_camera                      89 non-null     float64
#  19  player_id                       3628 non-null   float64
#  20  player_name                     3628 non-null   object
#  21  position_id                     3628 non-null   float64
#  22  position_name                   3628 non-null   object
#  23  pass_recipient_id               993 non-null    float64
#  24  pass_recipient_name             993 non-null    object
#  25  pass_length                     1020 non-null   float64
#  26  pass_angle                      1020 non-null   float64
#  27  pass_height_id                  1020 non-null   float64
#  28  pass_height_name                1020 non-null   object
#  29  end_x                           1886 non-null   float64
#  30  end_y                           1886 non-null   float64
#  31  sub_type_id                     272 non-null    float64
#  32  sub_type_name                   272 non-null    object
#  33  body_part_id                    1039 non-null   float64
#  34  body_part_name                  1039 non-null   object
#  35  x                               3614 non-null   float64
#  36  y                               3614 non-null   float64
#  37  pass_switch                     26 non-null     object
#  38  under_pressure                  707 non-null    float64
#  39  outcome_id                      444 non-null    float64
#  40  outcome_name                    444 non-null    object
#  41  counterpress                    101 non-null    float64
#  42  out                             25 non-null     float64
#  43  technique_id                    43 non-null     float64
#  44  technique_name                  43 non-null     object
#  45  dribble_nutmeg                  2 non-null      object
#  46  ball_recovery_recovery_failure  8 non-null      object
#  47  foul_won_defensive              9 non-null      object
#  48  pass_assisted_shot_id           16 non-null     object
#  49  pass_goal_assist                3 non-null      object
#  50  shot_statsbomb_xg               25 non-null     float64
#  51  end_z                           17 non-null     float64
#  52  shot_key_pass_id                16 non-null     object
#  53  goalkeeper_position_id          25 non-null     float64
#  54  goalkeeper_position_name        25 non-null     object
#  55  foul_committed_penalty          1 non-null      object
#  56  foul_won_penalty                1 non-null      object
#  57  pass_shot_assist                13 non-null     object
#  58  bad_behaviour_card_id           3 non-null      float64
#  59  bad_behaviour_card_name         3 non-null      object
#  60  aerial_won                      18 non-null     object
#  61  pass_cross                      11 non-null     object
#  62  pass_cut_back                   3 non-null      object
#  63  pass_no_touch                   1 non-null      object
#  64  foul_committed_offensive        2 non-null      object
#  65  substitution_replacement_id     6 non-null      float64
#  66  substitution_replacement_name   6 non-null      object
#  67  shot_first_time                 4 non-null      object
#  68  shot_one_on_one                 2 non-null      object
#  69  foul_committed_card_id          3 non-null      float64
#  70  foul_committed_card_name        3 non-null      object
#  71  block_offensive                 1 non-null      object
#  72  foul_committed_advantage        2 non-null      object
#  73  foul_won_advantage              3 non-null      object
#  74  pass_deflected                  1 non-null      object
# dtypes: float64(25), int64(10), object(40)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Dataset
#
# - per l'exemple que treballarem a continuació construim un dataset amb temps/posicions d'events relacionats amb en Messi (*player_id* = 5503)
#
# - la funció *isin(5503).any(axis = 1)* comprova (per files) si el valor 5503 existeix en qualsevol de les columnes

# %%
locs = events[events.isin([5503]).any(axis = 1)][['period', 'timestamp', 'duration', 'x', 'y', 'end_x', 'end_y','type_id', 'type_name']]
locs.sort_values(by = ['period', 'timestamp'], inplace = True)
locs.head()
# Out:
#      period        timestamp  duration     x     y  end_x  end_y  type_id  \
# 98        1  00:01:32.943000  0.000000  53.9  37.8    NaN    NaN        2
# 99        1  00:01:32.943000  0.275743  53.9  37.8   53.5   35.9       43
# 101       1  00:01:33.219000  0.000000  53.5  35.9    NaN    NaN       14
# 102       1  00:01:33.219000  3.642478  53.5  35.9   52.2   27.0       43
# 103       1  00:01:36.861000  1.285932  52.2  27.0   63.6   44.3       30
#
#          type_name
# 98   Ball Recovery
# 99           Carry
# 101        Dribble
# 102          Carry
# 103           Pass

# %% [markdown]
# - l'*scatterplot* ens situa aquests events en el camp (coordenades *x*, *y*)
# - separem els events per períodes

# %%
fig, axs = pitch.grid(nrows = 1, ncols = 2, space = 0.1, title_height = 0, endnote_height = 0)
axs[0].scatter(locs.x[locs.period == 1], locs.y[locs.period == 1], c = 'b');
axs[1].scatter(locs.x[locs.period == 2], locs.y[locs.period == 2], c = 'r');
# Primera part vs segona part
