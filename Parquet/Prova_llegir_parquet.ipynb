# %%
import pandas as pd
import pyarrow

# %%
parquet_file = "1.parquet"
df1 = pd.read_parquet(parquet_file, engine='pyarrow')

# %%
df1
# Out:
#      tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0       26.0     18.1  22.4          26.0          18.1       22.4  16.5
# 1       30.5     14.8  22.5          32.0          14.8       22.9  16.5
# 2       27.6     17.0  22.5          28.7          17.0       22.7  16.6
# 3       28.9     16.1  22.6          30.1          16.1       22.8  16.5
# 4       27.2     17.4  22.5          28.3          17.4       22.6  16.6
# ..       ...      ...   ...           ...           ...        ...   ...
# 942     30.2     15.1  22.6          31.7          15.1       22.9  16.6
# 943     28.9     18.1  23.4          29.2          18.1       23.6  17.3
# 944     29.3     16.3  22.2          28.7          16.3       22.2  15.0
# 945     29.0     18.0  23.3          29.1          18.0       23.4  17.1
# 946     28.2     19.4  23.8          29.0          19.4       24.1  18.1
#
#      humidity  snow  snowdepth  ...  pressure  cloudcover  visibility  \
# ...

# %%
parquet_file = "2.parquet"
df2 = pd.read_parquet(parquet_file, engine='pyarrow')

# %%
df2
# Out:
#      tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0       24.1     20.8  22.4          24.1          20.8       22.4  19.3
# 1       27.3     19.0  22.8          28.2          19.0       22.8  18.4
# 2       24.8     20.6  22.4          24.8          20.6       22.4  19.0
# 3       25.8     20.0  22.6          25.8          20.0       22.6  18.7
# 4       24.5     20.8  22.4          24.5          20.8       22.4  19.1
# ..       ...      ...   ...           ...           ...        ...   ...
# 942     26.9     19.3  22.7          27.9          19.3       22.8  18.5
# 943     25.2     22.0  23.5          25.2          22.0       23.5  17.8
# 944     23.9     19.5  22.0          23.9          19.5       22.0  16.9
# 945     25.0     22.0  23.3          25.0          22.0       23.3  17.6
# 946     25.5     22.5  24.0          25.5          22.5       24.0  18.5
#
#      humidity  snow  snowdepth  ...  pressure  cloudcover  visibility  \
# ...
